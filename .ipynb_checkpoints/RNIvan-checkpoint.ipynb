# %% [markdown]
# <center>
#     <h1 style="color: #3498db;">Aplicación de Redes Neuronales Recurrentes para la serie del Atleta Colombiano Iván</h1>
# </center>

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Librerías Necesarias</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import tensorflow as tf
from datetime import timedelta

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, TimeSeriesSplit, GridSearchCV

import tensorflow.keras as keras

#from keras import initializers
#from tensorflow.keras.layers import Dense, Layer, LSTM, GRU, SimpleRNN, RNN
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.models import load_model
#from tensorflow.keras.regularizers import l1, l2
#from tensorflow.keras.callbacks import EarlyStopping
#from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %%
# %matplotlib inline

# %%
import gc
gc.collect()
# Out:
# 4

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Descripción de la serie</h2>

# %%
ruta = r"C:\Users\Lenovo\Desktop\Escritorio\Serie_Ivan.xlsx"

# Lee el archivo Excel
df = pd.read_excel(ruta,index_col=0)
# Muestra las primeras filas del DataFrame
print(df.head())
df.size
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# 268

# %%
df.index = pd.to_datetime(df.index, infer_datetime_format=True)

# %%
df
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8
#
# [268 rows x 1 columns]

# %%
nof_missing_values = sum(np.isnan(df['KMS']))

print(nof_missing_values, 'observations are missing.')
print('This is {:.3f}% of the total.'.format(nof_missing_values*100/len(df)))
# Out:
# 0 observations are missing.
# This is 0.000% of the total.

# %%
df = df.fillna(method="backfill")
nof_missing_values = sum(np.isnan(df['KMS']))

print('Now', nof_missing_values, 'observations are missing.')
# Out:
# Now 0 observations are missing.

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">RNN Regression</h2>

# %%
use_features = ['KMS'] # continuous input
target = ['KMS'] # continuous output
n_steps_ahead = 12 # forecasting horizon

# %%
plt.plot(df['KMS'])

# %%
# Eliminar la primera fila que tendrá un NaN después de la diferenciación
df.dropna(inplace=True)
print(df)
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8
#
# [268 rows x 1 columns]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Estacionariedad</h2>

# %% [markdown]
# Es esencial determinar si la serie de tiempo es "estacionaria". Informalmente, la estacionariedad ocurre cuando la autocovarianza es independiente del tiempo. No establecer la estacionariedad casi con certeza conducirá a una mala interpretación de la identificación del modelo y las pruebas diagnósticas. Además, la estacionariedad es decisiva para caracterizar el problema de predicción y determinar si se debe usar una arquitectura más avanzada. En particular, podemos esperar que una RNN simple funcione mal si los datos no son estacionarios, ya que la RNN presenta una autocovarianza fija.
#
# Realizamos una prueba de Dickey-Fuller Aumentada para establecer la estacionariedad bajo el supuesto de que la serie de tiempo tiene un sesgo constante pero no presenta una tendencia temporal. En otras palabras, asumimos que la serie de tiempo ya está des-trendida.
#
# Si la prueba de estacionariedad falla, incluso después de des-trender la serie de tiempo, entonces un recurso potencial es simplemente tomar diferencias de la serie de tiempo y predecir $\Delta y_t$.

# %%
sample = df['KMS'][:268]
adf, p, usedlag, nobs, cvs, aic = sm.tsa.stattools.adfuller(sample)

# %%
adf_results_string = 'ADF: {}\np-value: {},\nN: {}, \ncritical values: {}'
print(adf_results_string.format(adf, p, nobs, cvs))
# Out:
# ADF: -8.294440147260046
# p-value: 4.1767430606472077e-13,
# N: 266,
# critical values: {'1%': -3.455175292841607, '5%': -2.8724677563219485, '10%': -2.57259315846006}

# %% [markdown]
# Aquí rechazamos la hipótesis nula ya que el valor p es menor que 0.01, por lo tanto,  podemos rechazar la prueba al nivel de confianza del 99%. Esto sugiere que la serie temporal  es **estacionaria**.

# %%
pacf = sm.tsa.stattools.pacf(df[use_features], nlags=52)
print(pacf)
# Out:
# [ 1.          0.35982968  0.1112808  -0.05356433  0.04189731 -0.03024228
#  -0.03798688 -0.00208805 -0.01438159  0.06928826  0.01587568 -0.11641937
#  -0.04475874 -0.02741998  0.01813617  0.047017    0.0398394   0.02744579
#  -0.04711411  0.01880179 -0.03288715  0.04010612 -0.04665097 -0.00705715
#  -0.06939977 -0.08739706 -0.12940267 -0.04402874  0.12694111  0.03792325
#   0.10913632 -0.05427822  0.02069914  0.04766867 -0.01439542  0.11169568
#  -0.01045524  0.09871045 -0.12141682  0.07815533 -0.09998191 -0.07975051
#   0.01579923  0.0805939   0.04519596  0.07646898  0.03325565 -0.09312151
#   0.02436844  0.10388561  0.0086983   0.00908146  0.14322692]

# %%
T = len(df[use_features])
sig_test = lambda tau_h: np.abs(tau_h) > 2.58/np.sqrt(T)
df[use_features].head()
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5

# %%
for i in range(len(pacf)):
    if sig_test(pacf[i]) == False:
        n_steps = i - 1
        print('n_steps set to', n_steps)
        break
# Out:
# n_steps set to 1

# %%
plt.plot(pacf, label='pacf')
plt.plot([2.58/np.sqrt(T)]*52, label='99% confidence interval (upper)')
plt.plot([-2.58/np.sqrt(T)]*52, label='99% confidence interval (lower)')
plt.xlabel('number of lags')
plt.legend();

# %% [markdown]
# Por lo que para este caso el número de retardos significartivo es de **1**.

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;"> Dividiendo la serie temporal en conjuntos de entrenamiento y prueba</h2>

# %%
train_weight = 0.8
split = int(len(df) * train_weight)

df_train = df[use_features].iloc[:split]
df_test = df[use_features].iloc[split:]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Estandarización de los datos</h2>

# %% [markdown]
# La estandarización de los datos es importante para evitar posibles dificultades de escala en el ajuste del modelo. Cuando hay más de una característica (covariable), la estandarización evita que una característica domine sobre otra debido a escalas dispares.
# Para evitar introducir un sesgo de anticipación en la predicción, debemos reescalar los datos de entrenamiento sin conocimiento del conjunto de prueba. Por lo tanto, simplemente estandarizaremos el conjunto de entrenamiento utilizando la media y la desviación estándar del conjunto de entrenamiento y no de toda la serie temporal. Además, para evitar introducir un sesgo sistemático en el conjunto de prueba, utilizamos la misma normalización para el conjunto de prueba: la media y la desviación estándar del conjunto de entrenamiento se utilizan para normalizar el conjunto de prueba.

# %%
mu = float(df_train.mean())
sigma = float(df_train.std())
print(sigma)
print(mu)
stdize_input = lambda x: (x - mu) / sigma

df_train = df_train.apply(stdize_input)
df_test = df_test.apply(stdize_input)
print(df_train)
print(df_test)
# Out:
# 48.97102603165779
# 124.08225233644858
#                  KMS
# DATE
# 2018-12-31 -2.180519
# 2019-01-07 -0.769481
# 2019-01-14 -0.342698
# 2019-01-21  0.796752
# 2019-01-28  0.600717
# ...              ...
# 2023-01-02  1.550258
# 2023-01-09  1.517586
# 2023-01-16  1.164316
# 2023-01-23  1.621729
# 2023-01-30  0.574171
#
# [214 rows x 1 columns]
#                  KMS
# DATE
# 2023-02-06  0.472070
# 2023-02-13 -1.034944
# 2023-02-20 -1.453559
# 2023-02-27 -0.992061
# 2023-03-06  0.192313
# 2023-03-13  1.123475
# 2023-03-20 -0.363118
# 2023-03-27  1.774881
# 2023-04-03 -1.073742
# 2023-04-10 -0.532606
# 2023-04-17  1.025458
# 2023-04-24  1.182694
# 2023-05-01  1.111223
# 2023-05-08  0.823298
# 2023-05-15 -0.671463
# 2023-05-22  0.118800
# 2023-05-29  1.152064
# 2023-06-05  0.986660
# 2023-06-12  0.904979
# 2023-06-19  0.200481
# 2023-06-26  0.627264
# 2023-07-03 -1.059448
# 2023-07-10  0.958072
# 2023-07-17 -1.412718
# 2023-07-24 -0.330445
# 2023-07-31 -2.262200
# 2023-08-07  1.564553
# 2023-08-14 -0.030268
# 2023-08-21  1.364434
# 2023-08-28  1.270501
# 2023-09-04  1.262333
# 2023-09-11 -0.350866
# 2023-09-18  0.680356
# 2023-09-25 -1.814997
# 2023-10-02  0.337296
# 2023-10-09  1.007080
# 2023-10-16 -0.173210
# 2023-10-23  0.131052
# 2023-10-30 -1.147255
# 2023-11-06  0.465944
# 2023-11-13 -0.011890
# 2023-11-20 -0.879750
# 2023-11-27  0.463902
# 2023-12-04  0.398557
# 2023-12-11  1.321552
# 2023-12-18  1.593141
# 2023-12-25  0.043245
# 2024-01-01  1.678906
# 2024-01-08  1.774881
# 2024-01-15  1.595183
# 2024-01-22  1.568637
# 2024-01-29  0.747743
# 2024-02-05  0.237237
# 2024-02-12 -0.046604

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Data formatting for RNNs</h2>

# %% [markdown]
# TensorFlow utiliza tensores para representar los datos. Para realizar el aprendizaje de secuencias, la serie temporal de variables debe transformarse en una serie de subsecuencias superpuestas.

# %%
def get_lagged_features(df, n_steps, n_steps_ahead):
    """
    df: pandas DataFrame of time series to be lagged
    n_steps: number of lags, i.e. sequence length
    n_steps_ahead: forecasting horizon
    """
    lag_list = []
    
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append(df.shift(lag))
    lag_array = np.dstack([i[n_steps+n_steps_ahead-1:] for i in lag_list])
    # We swap the last two dimensions so each slice along the first dimension
    # is the same shape as the corresponding segment of the input time series 
    lag_array = np.swapaxes(lag_array, 1, -1)
    return lag_array

# %%
n_steps_ahead
# Out:
# 12

# %% [markdown]
# Primero transformaremos los datos de entrada y salida del entrenamiento

# %%
x_train = get_lagged_features(df_train, n_steps, n_steps_ahead)
y_train =  df_train.values[n_steps + n_steps_ahead - 1:]
y_train_timestamps = df_train.index[n_steps + n_steps_ahead - 1:]

x_test = get_lagged_features(df_test, n_steps, n_steps_ahead)
y_test =  df_test.values[n_steps + n_steps_ahead - 1:]
y_test_timestamps = df_test.index[n_steps + n_steps_ahead - 1:]

# %%
print(y_train_timestamps)
# Out:
# DatetimeIndex(['2019-03-25', '2019-04-01', '2019-04-08', '2019-04-15',
#                '2019-04-22', '2019-04-29', '2019-05-06', '2019-05-13',
#                '2019-05-20', '2019-05-27',
#                ...
#                '2022-11-28', '2022-12-05', '2022-12-12', '2022-12-19',
#                '2022-12-26', '2023-01-02', '2023-01-09', '2023-01-16',
#                '2023-01-23', '2023-01-30'],
#               dtype='datetime64[ns]', name='DATE', length=202, freq=None)

# %%
print(y_test_timestamps)
# Out:
# DatetimeIndex(['2023-05-01', '2023-05-08', '2023-05-15', '2023-05-22',
#                '2023-05-29', '2023-06-05', '2023-06-12', '2023-06-19',
#                '2023-06-26', '2023-07-03', '2023-07-10', '2023-07-17',
#                '2023-07-24', '2023-07-31', '2023-08-07', '2023-08-14',
#                '2023-08-21', '2023-08-28', '2023-09-04', '2023-09-11',
#                '2023-09-18', '2023-09-25', '2023-10-02', '2023-10-09',
#                '2023-10-16', '2023-10-23', '2023-10-30', '2023-11-06',
#                '2023-11-13', '2023-11-20', '2023-11-27', '2023-12-04',
#                '2023-12-11', '2023-12-18', '2023-12-25', '2024-01-01',
#                '2024-01-08', '2024-01-15', '2024-01-22', '2024-01-29',
#                '2024-02-05', '2024-02-12'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
print([tensor.shape for tensor in (x_train, y_train, x_test, y_test)])
# Out:
# [(202, 1, 1), (202, 1), (42, 1, 1), (42, 1)]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Especificación del modelo</h2>

# %% [markdown]
# **Red Neuronal Recurrente**

# %%
def SimpleRNN_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.SimpleRNN(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True, stateful=False))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.SimpleRNN:** Agrega una capa SimpleRNN al modelo.
# - **n_units:** Número de unidades/neuronas en la capa SimpleRNN.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa SimpleRNN para acelerar el entrenamiento si es posible.
# - **stateful=False:** No mantiene estados persistentes entre muestras.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %% [markdown]
# **Red Neuronal GRU**

# %%
def GRU_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.GRU(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.GRU:** Agrega una capa GRU al modelo.
# - **n_units:** Número de unidades/neuronas en la capa GRU.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa GRU para acelerar el entrenamiento si es posible.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %% [markdown]
# **Red Neuronal LSTM**

# %%
def LSTM_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.LSTM(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True)) 
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.LSTM:** Agrega una capa LSTM al modelo.
# - **n_units:** Número de unidades/neuronas en la capa LSTM.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa LSTM para acelerar el entrenamiento si es posible.
# - **1:** Una sola neurona en la capa densa para problemas de regresión.
# - **kernel_initializer, bias_initializer:** Inicializadores de pesos y sesgos para la capa densa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa densa.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %% [markdown]
# Utilice un tamaño de lote de 1000 ya que el conjunto de datos es razonablemente grande y de lo contrario el tiempo de entrenamiento sería demasiado largo. Se han utilizado 20 épocas aquí, pero un enfoque mejor sería utilizar un criterio de parada a través de un callback.

# %%
max_epochs = 20 #Dejar mil
batch_size = 1000

# %%
es = keras.callbacks.EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10, min_delta=1e-7, restore_best_weights=True)

# %%
params = {
    'rnn': {
        'model': None, 'function': SimpleRNN_, 'l1_reg': 0.0, 'H': 20, 
        'color': 'blue', 'label':'RNN'}, 
    'gru': {
        'model': None, 'function':GRU_,'l1_reg': 0.0, 'H': 10, 
        'color': 'orange', 'label': 'GRU'},
    'lstm': {
        'model': None, 'function': LSTM_,'l1_reg': 0.0, 'H': 10, 
        'color':'red', 'label': 'LSTM'}
}

# %%
params
# Out:
# {'rnn': {'model': None,
#   'function': <function __main__.SimpleRNN_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 20,
#   'color': 'blue',
#   'label': 'RNN'},
#  'gru': {'model': None,
#   'function': <function __main__.GRU_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 10,
#   'color': 'orange',
#   'label': 'GRU'},
#  'lstm': {'model': None,
#   'function': <function __main__.LSTM_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 10,
#   'color': 'red',
#   'label': 'LSTM'}}

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Cargando modelos preentrenados</h2>
#
# Entrenar los modelos lleva varias horas. Para ahorrar tiempo, puedes cargar los modelos ya ajustados en su lugar:

# %%
do_training = True # Set to True if you wish to train your own models

# %%
params.keys()
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
if do_training is False:
     for key in params.keys():
        params[key]['model']=keras.models.load_model('RNNs-Ivan-SAVED-' + key + '.hdf5')

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Validación cruzada</h2>

# %% [markdown]
# La celda siguiente realiza una búsqueda en cuadrícula para optimizar n_units y l1_reg para cada uno de los modelos utilizando los datos de entrenamiento.
#
# Los resultados se validan cruzadamente para evitar el sobreajuste. Se utiliza la función TimeSeriesSplit de Scikit-Learn para dividir los datos en 5 pares de conjuntos de entrenamiento y prueba, donde los datos de prueba siempre están adelante en el tiempo respecto a los datos de entrenamiento.

# %%
cross_val = True # WARNING: Changing this to True will take many hours to run

if do_training and cross_val:
    n_units = [5, 10, 20,30]
    l1_reg = [0, 0.001, 0.01, 0.1]
    
    # A dictionary containing a list of values to be iterated through
    # for each parameter of the model included in the search
    param_grid = {'n_units': n_units, 'l1_reg': l1_reg}
    
    # In the kth split, TimeSeriesSplit returns first k folds 
    # as training set and the (k+1)th fold as test set.
    tscv = TimeSeriesSplit(n_splits = 5)
    
    # A grid search is performed for each of the models, and the parameter set which
    # performs best over all the cross-validation splits is saved in the `params` dictionary
    for key in params.keys():
        print('Performing cross-validation. Model:', key)
        model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=params[key]['function'], epochs=max_epochs, 
                               batch_size=batch_size, verbose=2)
        #from scikeras.wrappers import KerasClassifier, KerasRegressor
        grid = GridSearchCV(estimator=model, param_grid=param_grid, 
                            cv=tscv, n_jobs=1, verbose=2)
        grid_result = grid.fit(x_train, y_train, callbacks=[es])
        print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
        
        means = grid_result.cv_results_['mean_test_score']
        stds = grid_result.cv_results_['std_test_score']
        params_ = grid_result.cv_results_['params']
        for mean, stdev, param_ in zip(means, stds, params_):
            print("%f (%f) with %r" % (mean, stdev, param_))
            
        params[key]['H'] = grid_result.best_params_['n_units']
        params[key]['l1_reg']= grid_result.best_params_['l1_reg']
# Out:
# Performing cross-validation. Model: rnn
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9716\2699852436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=params[key]['function'], epochs=max_epochs,
# Epoch 1/20
# 1/1 - 3s - loss: 1.5770 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 1.5697 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 1.5625 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 1.5553 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 1.5481 - 17ms/epoch - 17ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 1.5410 - 25ms/epoch - 25ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 1.5340 - 24ms/epoch - 24ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 1.5269 - 20ms/epoch - 20ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.5200 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.5131 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.5062 - 8ms/epoch - 8ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.4994 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.4926 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.4859 - 17ms/epoch - 17ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.4792 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.4725 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.4660 - 13ms/epoch - 13ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.4594 - 19ms/epoch - 19ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.4530 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.4465 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.5235 - 672ms/epoch - 672ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   5.4s
# Epoch 1/20
# 1/1 - 3s - loss: 2.1262 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.1169 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.1077 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.0984 - 0s/epoch - 0s/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.0893 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0802 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0711 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0622 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.0532 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.0444 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.0355 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.0268 - 0s/epoch - 0s/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.0181 - 0s/epoch - 0s/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.0095 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.0009 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.9924 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.9839 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.9755 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9672 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9589 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 1.4796 - 536ms/epoch - 536ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   4.1s
# Epoch 1/20
# 1/1 - 3s - loss: 1.9546 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 1.9464 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 1.9382 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 1.9301 - 8ms/epoch - 8ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 1.9220 - 13ms/epoch - 13ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 1.9139 - 17ms/epoch - 17ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 1.9060 - 18ms/epoch - 18ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 1.8980 - 7ms/epoch - 7ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.8901 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.8823 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.8745 - 17ms/epoch - 17ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.8668 - 23ms/epoch - 23ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.8591 - 17ms/epoch - 17ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.8515 - 26ms/epoch - 26ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.8440 - 17ms/epoch - 17ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.8365 - 11ms/epoch - 11ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.8290 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.8216 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.8143 - 20ms/epoch - 20ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.8070 - 8ms/epoch - 8ms/step
# 1/1 - 1s - loss: 2.2452 - 549ms/epoch - 549ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   4.9s
# Epoch 1/20
# 1/1 - 3s - loss: 2.0611 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.0529 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.0448 - 8ms/epoch - 8ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.0368 - 8ms/epoch - 8ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.0288 - 13ms/epoch - 13ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0208 - 17ms/epoch - 17ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0129 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0050 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.9972 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.9895 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.9818 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.9742 - 10ms/epoch - 10ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.9666 - 8ms/epoch - 8ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.9590 - 8ms/epoch - 8ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.9516 - 19ms/epoch - 19ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.9441 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.9368 - 15ms/epoch - 15ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.9295 - 17ms/epoch - 17ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9222 - 11ms/epoch - 11ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9150 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.2476 - 536ms/epoch - 536ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   5.6s
# Epoch 1/20
# 1/1 - 3s - loss: 2.1361 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.1275 - 18ms/epoch - 18ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.1190 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.1105 - 8ms/epoch - 8ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.1021 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0937 - 17ms/epoch - 17ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0853 - 25ms/epoch - 25ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0770 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.0688 - 21ms/epoch - 21ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.0606 - 8ms/epoch - 8ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.0525 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.0444 - 12ms/epoch - 12ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.0364 - 24ms/epoch - 24ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.0284 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.0205 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.0126 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.0048 - 10ms/epoch - 10ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.9971 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9894 - 18ms/epoch - 18ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9817 - 16ms/epoch - 16ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x000001C278B0D5E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 1s - loss: 2.5313 - 847ms/epoch - 847ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   4.9s
# Epoch 1/20
# 1/1 - 3s - loss: 2.4200 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.4048 - 8ms/epoch - 8ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.3896 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.3745 - 17ms/epoch - 17ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.3596 - 10ms/epoch - 10ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.3447 - 18ms/epoch - 18ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.3299 - 14ms/epoch - 14ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.3153 - 15ms/epoch - 15ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.3007 - 35ms/epoch - 35ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.2862 - 17ms/epoch - 17ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.2718 - 8ms/epoch - 8ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.2575 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.2434 - 12ms/epoch - 12ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.2293 - 17ms/epoch - 17ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.2153 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.2015 - 7ms/epoch - 7ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.1877 - 15ms/epoch - 15ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.1741 - 17ms/epoch - 17ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.1605 - 11ms/epoch - 11ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.1471 - 16ms/epoch - 16ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001C27E0CFF70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 1s - loss: 3.3728 - 528ms/epoch - 528ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   4.2s
# Epoch 1/20
# 1/1 - 4s - loss: 3.0477 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0297 - 21ms/epoch - 21ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0119 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.9941 - 25ms/epoch - 25ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.9766 - 19ms/epoch - 19ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.9591 - 15ms/epoch - 15ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9418 - 41ms/epoch - 41ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9246 - 27ms/epoch - 27ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9076 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.8906 - 9ms/epoch - 9ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.8739 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.8572 - 26ms/epoch - 26ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.8408 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8244 - 9ms/epoch - 9ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8082 - 15ms/epoch - 15ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.7921 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.7762 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.7604 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7447 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7292 - 24ms/epoch - 24ms/step
# 1/1 - 2s - loss: 2.0614 - 2s/epoch - 2s/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   6.6s
# Epoch 1/20
# 1/1 - 4s - loss: 2.8119 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.7954 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.7789 - 33ms/epoch - 33ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.7626 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.7463 - 27ms/epoch - 27ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.7302 - 15ms/epoch - 15ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.7142 - 23ms/epoch - 23ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.6983 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.6825 - 47ms/epoch - 47ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.6669 - 109ms/epoch - 109ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.6513 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.6359 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.6205 - 17ms/epoch - 17ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.6053 - 32ms/epoch - 32ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.5903 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.5753 - 95ms/epoch - 95ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.5605 - 32ms/epoch - 32ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.5458 - 77ms/epoch - 77ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.5312 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.5167 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.9189 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   6.5s
# Epoch 1/20
# 1/1 - 7s - loss: 2.9161 - 7s/epoch - 7s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.8994 - 47ms/epoch - 47ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.8827 - 47ms/epoch - 47ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.8662 - 31ms/epoch - 31ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.8498 - 47ms/epoch - 47ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.8335 - 47ms/epoch - 47ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.8173 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.8012 - 78ms/epoch - 78ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.7853 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.7694 - 78ms/epoch - 78ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.7537 - 31ms/epoch - 31ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.7381 - 31ms/epoch - 31ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.7227 - 31ms/epoch - 31ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.7073 - 31ms/epoch - 31ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.6921 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.6770 - 31ms/epoch - 31ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.6621 - 31ms/epoch - 31ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.6472 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.6325 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.6179 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.3962 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=  10.1s
# Epoch 1/20
# 1/1 - 7s - loss: 3.0942 - 7s/epoch - 7s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0763 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0585 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.0407 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.0231 - 31ms/epoch - 31ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.0056 - 31ms/epoch - 31ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9883 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9710 - 109ms/epoch - 109ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9539 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.9369 - 203ms/epoch - 203ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.9200 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.9032 - 47ms/epoch - 47ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.8866 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8701 - 31ms/epoch - 31ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8537 - 31ms/epoch - 31ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8375 - 31ms/epoch - 31ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8213 - 94ms/epoch - 94ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.8053 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7894 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7737 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.1160 - 985ms/epoch - 985ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=  10.1s
# Epoch 1/20
# 1/1 - 6s - loss: 2.7707 - 6s/epoch - 6s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.7452 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.7201 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.6952 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.6708 - 31ms/epoch - 31ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.6466 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.6227 - 31ms/epoch - 31ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.5992 - 47ms/epoch - 47ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.5759 - 31ms/epoch - 31ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.5530 - 31ms/epoch - 31ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.5303 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.5079 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.4857 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.4638 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.4422 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.4208 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.3996 - 0s/epoch - 0s/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.3787 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.3580 - 0s/epoch - 0s/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.3376 - 31ms/epoch - 31ms/step
# 1/1 - 1s - loss: 3.6319 - 984ms/epoch - 984ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   9.1s
# Epoch 1/20
# 1/1 - 9s - loss: 3.4205 - 9s/epoch - 9s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.3923 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.3644 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.3368 - 31ms/epoch - 31ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.3095 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2825 - 219ms/epoch - 219ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.2557 - 94ms/epoch - 94ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.2292 - 219ms/epoch - 219ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.2030 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1771 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1514 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.1260 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.1009 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0760 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0514 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0270 - 0s/epoch - 0s/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.0030 - 31ms/epoch - 31ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.9792 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.9556 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.9323 - 62ms/epoch - 62ms/step
# 1/1 - 2s - loss: 2.4037 - 2s/epoch - 2s/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=  13.6s
# Epoch 1/20
# 1/1 - 5s - loss: 3.2402 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.2129 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.1858 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.1590 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.1324 - 31ms/epoch - 31ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.1061 - 78ms/epoch - 78ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.0800 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.0542 - 31ms/epoch - 31ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.0287 - 31ms/epoch - 31ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.0034 - 31ms/epoch - 31ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.9784 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.9536 - 31ms/epoch - 31ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.9292 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.9049 - 47ms/epoch - 47ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8810 - 31ms/epoch - 31ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8573 - 63ms/epoch - 63ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8339 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.8108 - 31ms/epoch - 31ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7879 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7653 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.1827 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   8.5s
# Epoch 1/20
# 1/1 - 6s - loss: 3.3560 - 6s/epoch - 6s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.3281 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.3005 - 31ms/epoch - 31ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.2731 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.2460 - 31ms/epoch - 31ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2192 - 31ms/epoch - 31ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.1926 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.1663 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.1403 - 31ms/epoch - 31ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1145 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.0890 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.0638 - 47ms/epoch - 47ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.0389 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0143 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.9899 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.9658 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.9420 - 0s/epoch - 0s/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.9185 - 30ms/epoch - 30ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.8953 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.8723 - 31ms/epoch - 31ms/step
# 1/1 - 1s - loss: 3.8554 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   8.2s
# Epoch 1/20
# 1/1 - 5s - loss: 3.5988 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.5685 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.5384 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.5086 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.4790 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.4498 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.4208 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.3921 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.3637 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.3356 - 63ms/epoch - 63ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.3078 - 0s/epoch - 0s/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.2803 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.2531 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.2262 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.1995 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.1732 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.1472 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.1215 - 0s/epoch - 0s/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.0960 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.0709 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.2672 - 734ms/epoch - 734ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   6.6s
# Epoch 1/20
# 1/1 - 5s - loss: 3.5948 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.5524 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.5106 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.4693 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.4287 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.3887 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.3493 - 31ms/epoch - 31ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.3105 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.2723 - 31ms/epoch - 31ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.2347 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1978 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.1615 - 31ms/epoch - 31ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.1258 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0906 - 31ms/epoch - 31ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0561 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0222 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.9889 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.9561 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.9239 - 31ms/epoch - 31ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.8923 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 4.2781 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   7.9s
# Epoch 1/20
# 1/1 - 4s - loss: 4.2762 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 4.2333 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 4.1909 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 4.1489 - 47ms/epoch - 47ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 4.1075 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 4.0665 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 4.0260 - 31ms/epoch - 31ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.9860 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.9464 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.9073 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.8687 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.8305 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.7928 - 31ms/epoch - 31ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.7555 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.7187 - 31ms/epoch - 31ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.6824 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.6465 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.6110 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.5761 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.5415 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.0683 - 1s/epoch - 1s/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   7.2s
# Epoch 1/20
# 1/1 - 3s - loss: 4.1553 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 4.1103 - 31ms/epoch - 31ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 4.0658 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 4.0220 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.9787 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.9361 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.8942 - 31ms/epoch - 31ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.8529 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.8121 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.7720 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.7325 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.6936 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.6553 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.6176 - 31ms/epoch - 31ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.5804 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.5438 - 31ms/epoch - 31ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.5078 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.4723 - 31ms/epoch - 31ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.4373 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.4029 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.8615 - 672ms/epoch - 672ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   5.3s
# Epoch 1/20
# 1/1 - 3s - loss: 4.3033 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 4.2564 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 4.2101 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 4.1645 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 4.1196 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 4.0754 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 4.0318 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.9889 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.9467 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.9052 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.8643 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.8241 - 31ms/epoch - 31ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.7845 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.7456 - 94ms/epoch - 94ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.7073 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.6696 - 31ms/epoch - 31ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.6325 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.5961 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.5602 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.5249 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 4.8467 - 922ms/epoch - 922ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   5.7s
# Epoch 1/20
# 1/1 - 3s - loss: 4.6510 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 4.5994 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 4.5484 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 4.4983 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 4.4488 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 4.4001 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 4.3522 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 4.3050 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 4.2585 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 4.2128 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 4.1678 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 4.1236 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 4.0800 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 4.0372 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.9950 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.9536 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.9128 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.8727 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.8333 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.7945 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.8962 - 735ms/epoch - 735ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   5.3s
# Epoch 1/20
# 1/1 - 3s - loss: 1.5817 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 1.5744 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 1.5672 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 1.5600 - 15ms/epoch - 15ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 1.5528 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 1.5457 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 1.5386 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 1.5316 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.5246 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.5177 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.5108 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.5040 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.4972 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.4904 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.4837 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.4771 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.4705 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.4640 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.4575 - 31ms/epoch - 31ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.4511 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.5280 - 594ms/epoch - 594ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   5.6s
# Epoch 1/20
# 1/1 - 3s - loss: 2.1310 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.1216 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.1124 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.1031 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.0940 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0849 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0758 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0668 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.0579 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.0490 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.0401 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.0314 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.0227 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.0140 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.0054 - 0s/epoch - 0s/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.9969 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.9885 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.9801 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9717 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9634 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 1.4841 - 750ms/epoch - 750ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   4.9s
# Epoch 1/20
# 1/1 - 2s - loss: 1.9594 - 2s/epoch - 2s/step
# Epoch 2/20
# 1/1 - 0s - loss: 1.9511 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 1.9429 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 1.9348 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 1.9267 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 1.9186 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 1.9106 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 1.9027 - 31ms/epoch - 31ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.8948 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.8869 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.8791 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.8714 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.8637 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.8561 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.8485 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.8410 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.8336 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.8262 - 0s/epoch - 0s/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.8188 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.8115 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.2497 - 750ms/epoch - 750ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   4.1s
# Epoch 1/20
# 1/1 - 4s - loss: 2.0658 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.0576 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.0495 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.0414 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.0334 - 64ms/epoch - 64ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0255 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0175 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0097 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.0019 - 31ms/epoch - 31ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.9941 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.9864 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.9788 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.9712 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.9636 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.9561 - 0s/epoch - 0s/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.9487 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.9413 - 15ms/epoch - 15ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.9340 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9268 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9195 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.2521 - 687ms/epoch - 687ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   5.3s
# Epoch 1/20
# 1/1 - 5s - loss: 2.1408 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.1322 - 17ms/epoch - 17ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.1237 - 9ms/epoch - 9ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.1152 - 10ms/epoch - 10ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.1067 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.0983 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.0900 - 13ms/epoch - 13ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.0817 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.0734 - 22ms/epoch - 22ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.0652 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.0571 - 10ms/epoch - 10ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.0490 - 15ms/epoch - 15ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.0410 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.0330 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.0251 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.0172 - 17ms/epoch - 17ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.0094 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.0016 - 14ms/epoch - 14ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.9939 - 17ms/epoch - 17ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.9862 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.5358 - 707ms/epoch - 707ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   6.8s
# Epoch 1/20
# 1/1 - 4s - loss: 2.4275 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.4123 - 28ms/epoch - 28ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.3971 - 13ms/epoch - 13ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.3820 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.3670 - 17ms/epoch - 17ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.3521 - 13ms/epoch - 13ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.3373 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.3226 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.3080 - 30ms/epoch - 30ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.2935 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.2792 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.2649 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.2507 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.2366 - 12ms/epoch - 12ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.2226 - 17ms/epoch - 17ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.2087 - 19ms/epoch - 19ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.1949 - 24ms/epoch - 24ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.1813 - 11ms/epoch - 11ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.1677 - 8ms/epoch - 8ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.1542 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.3800 - 860ms/epoch - 860ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.8s
# Epoch 1/20
# 1/1 - 4s - loss: 3.0552 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0372 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0194 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.0016 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.9840 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.9665 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9492 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9320 - 17ms/epoch - 17ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9149 - 26ms/epoch - 26ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.8980 - 12ms/epoch - 12ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.8812 - 14ms/epoch - 14ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.8646 - 17ms/epoch - 17ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.8480 - 12ms/epoch - 12ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8317 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8154 - 12ms/epoch - 12ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.7994 - 13ms/epoch - 13ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.7834 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.7676 - 8ms/epoch - 8ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7519 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7364 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 2.0686 - 642ms/epoch - 642ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.3s
# Epoch 1/20
# 1/1 - 3s - loss: 2.8195 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.8029 - 15ms/epoch - 15ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.7864 - 8ms/epoch - 8ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.7700 - 9ms/epoch - 9ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.7538 - 8ms/epoch - 8ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.7376 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.7216 - 11ms/epoch - 11ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.7057 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.6899 - 23ms/epoch - 23ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.6742 - 26ms/epoch - 26ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.6586 - 9ms/epoch - 9ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.6432 - 0s/epoch - 0s/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.6278 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.6126 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.5975 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.5825 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.5677 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.5529 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.5383 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.5238 - 23ms/epoch - 23ms/step
# 1/1 - 1s - loss: 2.9260 - 867ms/epoch - 867ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.2s
# Epoch 1/20
# 1/1 - 4s - loss: 2.9236 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.9069 - 10ms/epoch - 10ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.8902 - 8ms/epoch - 8ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.8737 - 8ms/epoch - 8ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.8572 - 6ms/epoch - 6ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.8409 - 13ms/epoch - 13ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.8247 - 13ms/epoch - 13ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.8086 - 13ms/epoch - 13ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.7926 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.7768 - 24ms/epoch - 24ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.7611 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.7455 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.7300 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.7146 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.6994 - 9ms/epoch - 9ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.6843 - 9ms/epoch - 9ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.6693 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.6544 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.6397 - 22ms/epoch - 22ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.6251 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.4033 - 617ms/epoch - 617ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.2s
# Epoch 1/20
# 1/1 - 3s - loss: 3.1018 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0838 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0659 - 24ms/epoch - 24ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.0482 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.0306 - 8ms/epoch - 8ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.0131 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9957 - 17ms/epoch - 17ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9784 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9613 - 21ms/epoch - 21ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.9442 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.9273 - 11ms/epoch - 11ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.9106 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.8939 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8774 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8610 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8447 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8285 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.8125 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7966 - 26ms/epoch - 26ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7808 - 17ms/epoch - 17ms/step
# 1/1 - 1s - loss: 3.1231 - 748ms/epoch - 748ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.0s
# Epoch 1/20
# 1/1 - 3s - loss: 2.7814 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.7559 - 21ms/epoch - 21ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.7307 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.7058 - 15ms/epoch - 15ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.6813 - 17ms/epoch - 17ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.6571 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.6332 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.6096 - 8ms/epoch - 8ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.5863 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.5633 - 17ms/epoch - 17ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.5406 - 8ms/epoch - 8ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.5181 - 0s/epoch - 0s/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.4959 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.4740 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.4523 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.4308 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.4097 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.3887 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.3680 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.3475 - 0s/epoch - 0s/step
# 1/1 - 1s - loss: 3.6418 - 652ms/epoch - 652ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   5.0s
# Epoch 1/20
# 1/1 - 3s - loss: 3.4312 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.4029 - 25ms/epoch - 25ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.3750 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.3474 - 25ms/epoch - 25ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.3200 - 10ms/epoch - 10ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2929 - 16ms/epoch - 16ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.2662 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.2396 - 8ms/epoch - 8ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.2134 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1874 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1617 - 15ms/epoch - 15ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.1363 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.1111 - 17ms/epoch - 17ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0862 - 11ms/epoch - 11ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0615 - 12ms/epoch - 12ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0371 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.0130 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.9892 - 11ms/epoch - 11ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.9656 - 14ms/epoch - 14ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.9422 - 24ms/epoch - 24ms/step
# 1/1 - 1s - loss: 2.4136 - 729ms/epoch - 729ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   4.5s
# Epoch 1/20
# 1/1 - 4s - loss: 3.2509 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.2235 - 25ms/epoch - 25ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.1964 - 9ms/epoch - 9ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.1695 - 10ms/epoch - 10ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.1429 - 10ms/epoch - 10ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.1166 - 11ms/epoch - 11ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.0905 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.0646 - 18ms/epoch - 18ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.0390 - 13ms/epoch - 13ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.0137 - 18ms/epoch - 18ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.9887 - 0s/epoch - 0s/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.9639 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.9394 - 18ms/epoch - 18ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.9151 - 14ms/epoch - 14ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8911 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8674 - 16ms/epoch - 16ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8440 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.8208 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7979 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7752 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.1926 - 680ms/epoch - 680ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   5.6s
# Epoch 1/20
# 1/1 - 3s - loss: 3.3667 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.3388 - 20ms/epoch - 20ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.3111 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.2837 - 11ms/epoch - 11ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.2565 - 12ms/epoch - 12ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2296 - 12ms/epoch - 12ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.2030 - 17ms/epoch - 17ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.1767 - 19ms/epoch - 19ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.1506 - 14ms/epoch - 14ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1248 - 17ms/epoch - 17ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.0993 - 15ms/epoch - 15ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.0741 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.0491 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0244 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0000 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.9759 - 0s/epoch - 0s/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.9521 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.9285 - 16ms/epoch - 16ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.9053 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.8823 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.8653 - 729ms/epoch - 729ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   4.9s
# Epoch 1/20
# 1/1 - 3s - loss: 3.6095 - 3s/epoch - 3s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.5791 - 18ms/epoch - 18ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.5490 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.5191 - 17ms/epoch - 17ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.4895 - 8ms/epoch - 8ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.4602 - 7ms/epoch - 7ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.4312 - 15ms/epoch - 15ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.4025 - 17ms/epoch - 17ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.3741 - 11ms/epoch - 11ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.3459 - 27ms/epoch - 27ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.3181 - 16ms/epoch - 16ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.2906 - 17ms/epoch - 17ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.2633 - 17ms/epoch - 17ms/step
# ...
# Epoch 16/20
# 1/1 - 0s - loss: 2.6321 - 13ms/epoch - 13ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.6243 - 13ms/epoch - 13ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.6167 - 14ms/epoch - 14ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.6090 - 14ms/epoch - 14ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.6013 - 15ms/epoch - 15ms/step
# 1/1 - 1s - loss: 3.0694 - 672ms/epoch - 672ms/step
# [CV] END .............................l1_reg=0.1, n_units=10; total time=   5.8s
# Epoch 1/20
# 1/1 - 5s - loss: 2.5757 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.5638 - 27ms/epoch - 27ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.5519 - 45ms/epoch - 45ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.5399 - 19ms/epoch - 19ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.5280 - 9ms/epoch - 9ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.5162 - 17ms/epoch - 17ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.5043 - 17ms/epoch - 17ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.4924 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.4806 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.4688 - 17ms/epoch - 17ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.4570 - 18ms/epoch - 18ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.4452 - 17ms/epoch - 17ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.4336 - 17ms/epoch - 17ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.4220 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.4105 - 18ms/epoch - 18ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.3989 - 26ms/epoch - 26ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.3873 - 64ms/epoch - 64ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.3759 - 65ms/epoch - 65ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.3646 - 55ms/epoch - 55ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.3534 - 25ms/epoch - 25ms/step
# 1/1 - 2s - loss: 2.8961 - 2s/epoch - 2s/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   7.9s
# Epoch 1/20
# 1/1 - 8s - loss: 2.8413 - 8s/epoch - 8s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.8291 - 14ms/epoch - 14ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.8169 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.8048 - 15ms/epoch - 15ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.7927 - 14ms/epoch - 14ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.7806 - 13ms/epoch - 13ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.7685 - 14ms/epoch - 14ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.7564 - 13ms/epoch - 13ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.7443 - 18ms/epoch - 18ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.7323 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.7203 - 9ms/epoch - 9ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.7083 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.6965 - 16ms/epoch - 16ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.6847 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.6729 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.6611 - 31ms/epoch - 31ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.6494 - 16ms/epoch - 16ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.6377 - 47ms/epoch - 47ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.6262 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.6147 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.2631 - 1s/epoch - 1s/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=  11.3s
# Epoch 1/20
# 1/1 - 8s - loss: 3.0599 - 8s/epoch - 8s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0474 - 17ms/epoch - 17ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0348 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.0222 - 20ms/epoch - 20ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.0097 - 14ms/epoch - 14ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.9972 - 18ms/epoch - 18ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9847 - 17ms/epoch - 17ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9722 - 22ms/epoch - 22ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9598 - 20ms/epoch - 20ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.9473 - 20ms/epoch - 20ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.9349 - 17ms/epoch - 17ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.9225 - 17ms/epoch - 17ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.9103 - 17ms/epoch - 17ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8981 - 17ms/epoch - 17ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8859 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8737 - 17ms/epoch - 17ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8616 - 17ms/epoch - 17ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.8496 - 17ms/epoch - 17ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.8377 - 18ms/epoch - 18ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.8259 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.6909 - 1s/epoch - 1s/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=  10.9s
# Epoch 1/20
# 1/1 - 4s - loss: 3.2754 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.2627 - 17ms/epoch - 17ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.2500 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.2373 - 25ms/epoch - 25ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.2246 - 17ms/epoch - 17ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2120 - 15ms/epoch - 15ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.1993 - 18ms/epoch - 18ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.1867 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.1741 - 17ms/epoch - 17ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1616 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1490 - 17ms/epoch - 17ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.1365 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.1241 - 21ms/epoch - 21ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.1118 - 19ms/epoch - 19ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0995 - 15ms/epoch - 15ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0872 - 25ms/epoch - 25ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.0749 - 19ms/epoch - 19ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.0628 - 32ms/epoch - 32ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.0508 - 22ms/epoch - 22ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.0388 - 38ms/epoch - 38ms/step
# 1/1 - 1s - loss: 2.7993 - 859ms/epoch - 859ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   6.7s
# Epoch 1/20
# 1/1 - 4s - loss: 3.2319 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.2191 - 14ms/epoch - 14ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.2064 - 13ms/epoch - 13ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.1937 - 17ms/epoch - 17ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.1809 - 20ms/epoch - 20ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.1682 - 18ms/epoch - 18ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.1556 - 16ms/epoch - 16ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.1429 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.1303 - 15ms/epoch - 15ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1176 - 14ms/epoch - 14ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1050 - 15ms/epoch - 15ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.0925 - 15ms/epoch - 15ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.0801 - 13ms/epoch - 13ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0677 - 14ms/epoch - 14ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0554 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0430 - 15ms/epoch - 15ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.0307 - 13ms/epoch - 13ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.0185 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.0065 - 16ms/epoch - 16ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.9944 - 14ms/epoch - 14ms/step
# 1/1 - 1s - loss: 3.5305 - 731ms/epoch - 731ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   6.2s
# Epoch 1/20
# 1/1 - 4s - loss: 2.8267 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 2.8098 - 13ms/epoch - 13ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 2.7929 - 14ms/epoch - 14ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 2.7763 - 13ms/epoch - 13ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.7597 - 16ms/epoch - 16ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.7431 - 18ms/epoch - 18ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.7265 - 28ms/epoch - 28ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.7098 - 15ms/epoch - 15ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.6932 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.6767 - 16ms/epoch - 16ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.6605 - 15ms/epoch - 15ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.6445 - 14ms/epoch - 14ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.6287 - 21ms/epoch - 21ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.6128 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.5970 - 38ms/epoch - 38ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.5814 - 18ms/epoch - 18ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.5657 - 18ms/epoch - 18ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.5499 - 25ms/epoch - 25ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.5342 - 41ms/epoch - 41ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.5189 - 29ms/epoch - 29ms/step
# 1/1 - 1s - loss: 3.0042 - 774ms/epoch - 774ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.1s
# Epoch 1/20
# 1/1 - 5s - loss: 3.0653 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.0483 - 14ms/epoch - 14ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.0312 - 17ms/epoch - 17ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.0145 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 2.9977 - 17ms/epoch - 17ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 2.9810 - 15ms/epoch - 15ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 2.9642 - 15ms/epoch - 15ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 2.9475 - 17ms/epoch - 17ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 2.9307 - 15ms/epoch - 15ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 2.9140 - 14ms/epoch - 14ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 2.8977 - 14ms/epoch - 14ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 2.8815 - 17ms/epoch - 17ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 2.8656 - 18ms/epoch - 18ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 2.8496 - 15ms/epoch - 15ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 2.8336 - 19ms/epoch - 19ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 2.8178 - 17ms/epoch - 17ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 2.8020 - 15ms/epoch - 15ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 2.7862 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.7703 - 15ms/epoch - 15ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.7549 - 14ms/epoch - 14ms/step
# 1/1 - 1s - loss: 3.4131 - 718ms/epoch - 718ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   7.3s
# Epoch 1/20
# 1/1 - 4s - loss: 3.2918 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.2742 - 15ms/epoch - 15ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.2566 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.2393 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.2220 - 15ms/epoch - 15ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.2047 - 14ms/epoch - 14ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.1874 - 15ms/epoch - 15ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.1700 - 13ms/epoch - 13ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.1528 - 11ms/epoch - 11ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.1355 - 12ms/epoch - 12ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.1186 - 13ms/epoch - 13ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.1020 - 14ms/epoch - 14ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.0855 - 13ms/epoch - 13ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.0689 - 15ms/epoch - 15ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.0525 - 14ms/epoch - 14ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.0362 - 13ms/epoch - 13ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.0199 - 14ms/epoch - 14ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.0035 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 2.9872 - 13ms/epoch - 13ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 2.9712 - 16ms/epoch - 16ms/step
# 1/1 - 1s - loss: 3.8431 - 723ms/epoch - 723ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.1s
# Epoch 1/20
# 1/1 - 4s - loss: 3.5109 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.4931 - 16ms/epoch - 16ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.4753 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.4578 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.4403 - 15ms/epoch - 15ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.4228 - 12ms/epoch - 12ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.4053 - 13ms/epoch - 13ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.3878 - 14ms/epoch - 14ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.3703 - 13ms/epoch - 13ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.3529 - 13ms/epoch - 13ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.3358 - 13ms/epoch - 13ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.3190 - 15ms/epoch - 15ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.3023 - 13ms/epoch - 13ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.2856 - 13ms/epoch - 13ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.2689 - 14ms/epoch - 14ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.2525 - 13ms/epoch - 13ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.2360 - 14ms/epoch - 14ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.2194 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.2028 - 22ms/epoch - 22ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.1867 - 19ms/epoch - 19ms/step
# 1/1 - 1s - loss: 2.9109 - 726ms/epoch - 726ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.2s
# Epoch 1/20
# 1/1 - 4s - loss: 3.4609 - 4s/epoch - 4s/step
# Epoch 2/20
# 1/1 - 0s - loss: 3.4430 - 14ms/epoch - 14ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 3.4252 - 16ms/epoch - 16ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 3.4076 - 16ms/epoch - 16ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 3.3901 - 15ms/epoch - 15ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 3.3725 - 15ms/epoch - 15ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 3.3550 - 17ms/epoch - 17ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 3.3375 - 16ms/epoch - 16ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 3.3200 - 16ms/epoch - 16ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 3.3025 - 15ms/epoch - 15ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 3.2854 - 17ms/epoch - 17ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 3.2685 - 16ms/epoch - 16ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 3.2518 - 15ms/epoch - 15ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 3.2350 - 16ms/epoch - 16ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 3.2184 - 16ms/epoch - 16ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 3.2019 - 17ms/epoch - 17ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 3.1854 - 15ms/epoch - 15ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 3.1688 - 15ms/epoch - 15ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 3.1522 - 13ms/epoch - 13ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 3.1360 - 13ms/epoch - 13ms/step
# 1/1 - 1s - loss: 3.6377 - 688ms/epoch - 688ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.2s
# Epoch 1/20
# 1/1 - 5s - loss: 1.5705 - 5s/epoch - 5s/step
# Epoch 2/20
# 1/1 - 0s - loss: 1.5640 - 14ms/epoch - 14ms/step
# Epoch 3/20
# 1/1 - 0s - loss: 1.5575 - 12ms/epoch - 12ms/step
# Epoch 4/20
# 1/1 - 0s - loss: 1.5510 - 14ms/epoch - 14ms/step
# Epoch 5/20
# 1/1 - 0s - loss: 1.5445 - 15ms/epoch - 15ms/step
# Epoch 6/20
# 1/1 - 0s - loss: 1.5380 - 17ms/epoch - 17ms/step
# Epoch 7/20
# 1/1 - 0s - loss: 1.5315 - 13ms/epoch - 13ms/step
# Epoch 8/20
# 1/1 - 0s - loss: 1.5250 - 14ms/epoch - 14ms/step
# Epoch 9/20
# 1/1 - 0s - loss: 1.5185 - 13ms/epoch - 13ms/step
# Epoch 10/20
# 1/1 - 0s - loss: 1.5121 - 12ms/epoch - 12ms/step
# Epoch 11/20
# 1/1 - 0s - loss: 1.5056 - 14ms/epoch - 14ms/step
# Epoch 12/20
# 1/1 - 0s - loss: 1.4992 - 13ms/epoch - 13ms/step
# Epoch 13/20
# 1/1 - 0s - loss: 1.4928 - 12ms/epoch - 12ms/step
# Epoch 14/20
# 1/1 - 0s - loss: 1.4864 - 13ms/epoch - 13ms/step
# Epoch 15/20
# 1/1 - 0s - loss: 1.4800 - 12ms/epoch - 12ms/step
# Epoch 16/20
# 1/1 - 0s - loss: 1.4736 - 12ms/epoch - 12ms/step
# Epoch 17/20
# 1/1 - 0s - loss: 1.4673 - 14ms/epoch - 14ms/step
# Epoch 18/20
# 1/1 - 0s - loss: 1.4609 - 13ms/epoch - 13ms/step
# Epoch 19/20
# 1/1 - 0s - loss: 1.4546 - 14ms/epoch - 14ms/step
# Epoch 20/20
# 1/1 - 0s - loss: 1.4483 - 13ms/epoch - 13ms/step
# Best: -1.595721 using {'l1_reg': 0, 'n_units': 30}
# -1.826320 (0.370271) with {'l1_reg': 0, 'n_units': 5}
# -1.735402 (0.387016) with {'l1_reg': 0, 'n_units': 10}
# -1.715855 (0.351703) with {'l1_reg': 0, 'n_units': 20}
# -1.595721 (0.369654) with {'l1_reg': 0, 'n_units': 30}
# -1.833920 (0.370263) with {'l1_reg': 0.001, 'n_units': 5}
# -1.746863 (0.386987) with {'l1_reg': 0.001, 'n_units': 10}
# -1.732656 (0.351602) with {'l1_reg': 0.001, 'n_units': 20}
# -1.616320 (0.369763) with {'l1_reg': 0.001, 'n_units': 30}
# -1.902569 (0.368746) with {'l1_reg': 0.01, 'n_units': 5}
# -1.851279 (0.386086) with {'l1_reg': 0.01, 'n_units': 10}
# -1.881318 (0.349174) with {'l1_reg': 0.01, 'n_units': 20}
# -1.790991 (0.365127) with {'l1_reg': 0.01, 'n_units': 30}
# -2.566706 (0.368717) with {'l1_reg': 0.1, 'n_units': 5}
# -2.839747 (0.380330) with {'l1_reg': 0.1, 'n_units': 10}
# -3.235998 (0.346595) with {'l1_reg': 0.1, 'n_units': 20}
# -3.361798 (0.358231) with {'l1_reg': 0.1, 'n_units': 30}

# %% [markdown]
# #### Train cross-validated model

# %% [markdown]
# Si se realizó la búsqueda en cuadrícula, los parámetros n_units y l1_reg con el mejor rendimiento promedio a través de las divisiones de validación cruzada se utilizan para entrenar los modelos en el conjunto de entrenamiento completo. Si no se realizó, se utilizan los valores de la inicialización de params mencionados anteriormente.

# %%
if do_training is True:
    for key in params.keys():
        tf.random.set_seed(0)
        print('Training', key, 'model')
        model = params[key]['function'](params[key]['H'], params[key]['l1_reg'])
        model.fit(x_train, y_train, epochs=max_epochs, 
                  batch_size=batch_size, callbacks=[es], shuffle=False)
        params[key]['model'] = model
# Out:
# Training rnn model
# Epoch 1/20
# 1/1 [==============================] - 13s 13s/step - loss: 2.2359
# Epoch 2/20
# 1/1 [==============================] - 0s 32ms/step - loss: 2.2269
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 2.2178
# Epoch 4/20
# 1/1 [==============================] - 0s 36ms/step - loss: 2.2089
# Epoch 5/20
# 1/1 [==============================] - 0s 34ms/step - loss: 2.2000
# Epoch 6/20
# 1/1 [==============================] - 0s 94ms/step - loss: 2.1911
# Epoch 7/20
# 1/1 [==============================] - 0s 33ms/step - loss: 2.1823
# Epoch 8/20
# 1/1 [==============================] - 0s 77ms/step - loss: 2.1736
# Epoch 9/20
# 1/1 [==============================] - 0s 94ms/step - loss: 2.1649
# Epoch 10/20
# 1/1 [==============================] - 0s 33ms/step - loss: 2.1563
# Epoch 11/20
# 1/1 [==============================] - 0s 32ms/step - loss: 2.1477
# Epoch 12/20
# 1/1 [==============================] - 0s 67ms/step - loss: 2.1392
# Epoch 13/20
# 1/1 [==============================] - 0s 140ms/step - loss: 2.1307
# Epoch 14/20
# 1/1 [==============================] - 0s 38ms/step - loss: 2.1223
# Epoch 15/20
# 1/1 [==============================] - 0s 96ms/step - loss: 2.1140
# Epoch 16/20
# 1/1 [==============================] - 0s 26ms/step - loss: 2.1057
# Epoch 17/20
# 1/1 [==============================] - 0s 95ms/step - loss: 2.0975
# Epoch 18/20
# 1/1 [==============================] - 0s 100ms/step - loss: 2.0893
# Epoch 19/20
# 1/1 [==============================] - 0s 64ms/step - loss: 2.0812
# Epoch 20/20
# 1/1 [==============================] - 0s 84ms/step - loss: 2.0732
# Training gru model
# Epoch 1/20
# 1/1 [==============================] - 14s 14s/step - loss: 1.9388
# Epoch 2/20
# 1/1 [==============================] - 0s 48ms/step - loss: 1.9248
# Epoch 3/20
# 1/1 [==============================] - 0s 83ms/step - loss: 1.9109
# Epoch 4/20
# 1/1 [==============================] - 0s 117ms/step - loss: 1.8972
# Epoch 5/20
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8835
# Epoch 6/20
# 1/1 [==============================] - 0s 79ms/step - loss: 1.8700
# Epoch 7/20
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8566
# Epoch 8/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.8433
# Epoch 9/20
# 1/1 [==============================] - 0s 49ms/step - loss: 1.8302
# Epoch 10/20
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8171
# Epoch 11/20
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8042
# Epoch 12/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.7914
# Epoch 13/20
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7787
# Epoch 14/20
# 1/1 [==============================] - 0s 34ms/step - loss: 1.7661
# Epoch 15/20
# 1/1 [==============================] - 0s 116ms/step - loss: 1.7536
# Epoch 16/20
# 1/1 [==============================] - 0s 76ms/step - loss: 1.7413
# Epoch 17/20
# 1/1 [==============================] - 0s 27ms/step - loss: 1.7290
# Epoch 18/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.7169
# Epoch 19/20
# 1/1 [==============================] - 0s 95ms/step - loss: 1.7049
# Epoch 20/20
# 1/1 [==============================] - 0s 28ms/step - loss: 1.6930
# Training lstm model
# Epoch 1/20
# 1/1 [==============================] - 14s 14s/step - loss: 1.5705
# Epoch 2/20
# 1/1 [==============================] - 0s 37ms/step - loss: 1.5640
# Epoch 3/20
# 1/1 [==============================] - 0s 98ms/step - loss: 1.5575
# Epoch 4/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.5510
# Epoch 5/20
# 1/1 [==============================] - 0s 38ms/step - loss: 1.5445
# Epoch 6/20
# 1/1 [==============================] - 0s 46ms/step - loss: 1.5380
# Epoch 7/20
# 1/1 [==============================] - 0s 30ms/step - loss: 1.5315
# Epoch 8/20
# 1/1 [==============================] - 0s 29ms/step - loss: 1.5250
# Epoch 9/20
# 1/1 [==============================] - 0s 69ms/step - loss: 1.5185
# Epoch 10/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.5121
# Epoch 11/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.5056
# Epoch 12/20
# 1/1 [==============================] - 0s 67ms/step - loss: 1.4992
# Epoch 13/20
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4928
# Epoch 14/20
# 1/1 [==============================] - 0s 26ms/step - loss: 1.4864
# Epoch 15/20
# 1/1 [==============================] - 0s 114ms/step - loss: 1.4800
# Epoch 16/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.4736
# Epoch 17/20
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4673
# Epoch 18/20
# 1/1 [==============================] - 0s 27ms/step - loss: 1.4609
# Epoch 19/20
# 1/1 [==============================] - 0s 64ms/step - loss: 1.4546
# Epoch 20/20
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4483

# %%
for key in params.keys():
    params[key]['model'].save('RNNs-Ivan-SAVED-' + key + '.hdf5', overwrite=True)  # creates a HDF5 file

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Predicción</h2>

# %% [markdown]
# Ahora aplicaremos los modelos RNN ajustados al conjunto de entrenamiento y al conjunto de prueba por separado. Luego podemos evaluar informalmente el grado de sobreajuste

# %%
y_train= (y_train*sigma)+mu
y_test=(y_test*sigma)+mu

# %%
for key in params.keys():
    model = params[key]['model']
    model.summary()
    
    params[key]['pred_train'] = model.predict(x_train, verbose=1)
    params[key]['pred_train']=(params[key]['pred_train']*sigma)+mu
    params[key]['MSE_train'] = mean_squared_error(y_train, params[key]['pred_train'])
    
    params[key]['pred_test'] = model.predict(x_test, verbose=1) 
    params[key]['pred_test']=(params[key]['pred_test']*sigma)+mu
    params[key]['MSE_test'] = mean_squared_error(y_test, params[key]['pred_test'])
# Out:
# Model: "sequential_243"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_81 (SimpleRNN)   (None, 5)                 35
#
#  dense_243 (Dense)           (None, 1)                 6
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# Model: "sequential_244"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_81 (GRU)                (None, 20)                1380
#
#  dense_244 (Dense)           (None, 1)                 21
#
# =================================================================
# Total params: 1,401
# Trainable params: 1,401
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# Model: "sequential_245"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_81 (LSTM)              (None, 30)                3840
#
#  dense_245 (Dense)           (None, 1)                 31
#
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;"> Rendimiento del modelo</h2>

# %% [markdown]
# Finalmente evaluar el rendimiento del modelo dentro y fuera de muestra usando el MSE. Esperamos que el error medio sea mayor en el conjunto de prueba que en el conjunto de entrenamiento.

# %%
print('training set:', len(y_train))
print('testing set:', len(y_test))
# Out:
# training set: 202
# testing set: 42

# %%
print(params.keys())
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Devolviendo los valores a la escala original</h2>

# %%
print(sigma)
print(mu)
stdize_output = lambda x: (x *sigma) +mu
df_train = df_train.apply(stdize_output)
df_test = df_test.apply(stdize_output)
# Out:
# 48.97102603165779
# 124.08225233644858

# %%
d_train = df[use_features].iloc[:split]
d_test = df[use_features].iloc[split:]
print(d_train)
print(d_test)
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2023-01-02  200.0
# 2023-01-09  198.4
# 2023-01-16  181.1
# 2023-01-23  203.5
# 2023-01-30  152.2
#
# [214 rows x 1 columns]
#               KMS
# DATE
# 2023-02-06  147.2
# 2023-02-13   73.4
# 2023-02-20   52.9
# 2023-02-27   75.5
# 2023-03-06  133.5
# 2023-03-13  179.1
# 2023-03-20  106.3
# 2023-03-27  211.0
# 2023-04-03   71.5
# 2023-04-10   98.0
# 2023-04-17  174.3
# 2023-04-24  182.0
# 2023-05-01  178.5
# 2023-05-08  164.4
# 2023-05-15   91.2
# 2023-05-22  129.9
# 2023-05-29  180.5
# 2023-06-05  172.4
# 2023-06-12  168.4
# 2023-06-19  133.9
# 2023-06-26  154.8
# 2023-07-03   72.2
# 2023-07-10  171.0
# 2023-07-17   54.9
# 2023-07-24  107.9
# 2023-07-31   13.3
# 2023-08-07  200.7
# 2023-08-14  122.6
# 2023-08-21  190.9
# 2023-08-28  186.3
# 2023-09-04  185.9
# 2023-09-11  106.9
# 2023-09-18  157.4
# 2023-09-25   35.2
# 2023-10-02  140.6
# 2023-10-09  173.4
# 2023-10-16  115.6
# 2023-10-23  130.5
# 2023-10-30   67.9
# 2023-11-06  146.9
# 2023-11-13  123.5
# 2023-11-20   81.0
# 2023-11-27  146.8
# 2023-12-04  143.6
# 2023-12-11  188.8
# 2023-12-18  202.1
# 2023-12-25  126.2
# 2024-01-01  206.3
# 2024-01-08  211.0
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8

# %%
print(params.keys())
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
y_vals=(y_vals*sigma)+mu

# %%
max_pts = 10**4
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable. 

fig = plt.figure(figsize=(15,8))
x_vals = y_train_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_train'][l:u:ds]
    label = params[key]['label'] + ' (train MSE: %.2e)' % params[key]['MSE_train']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_train[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Training)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_test'][l:u:ds]
    label = params[key]['label'] + ' (test MSE: %.2e)' % params[key]['MSE_test']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_test[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Testing)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # e.g. (None, 100000) lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_test'][l:u:ds] - y_test[l:u:ds]
    label = params[key]['label'] + ' (test MSE: %.2e)' % params[key]['MSE_test']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
plt.axhline(0, linewidth=0.8)
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=80)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}-Y$', fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Error (Testing)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot - e.g. (None, 10000)
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_train_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_train'][l:u:ds] - y_train[l:u:ds]
    label = params[key]['label'] + ' (train MSE: %.2e)' % params[key]['MSE_train']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
plt.axhline(0, linewidth=0.8)
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=80)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}-Y$', fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Error (Training)', fontsize=16);

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Diagnóstico del modelo</h2>

# %% [markdown]
# Un modelo ajustado de series temporales debe ser examinado para la subajustado con una prueba de ruido blanco. Analizamos los residuos del modelo (es decir, el error) para determinar si es ruido blanco o si está autocorrelacionado. En el último caso, esto proporciona evidencia estadística de que se necesitan más rezagos en la RNN.

# %%
# number of samples to use for computing test statistic
n = 100000

# %%
params.keys()
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
key = 'rnn'
predicted = params[key]['pred_test']
residual = y_test[-n:] - predicted[-n:]

# %%
statistic_lb = sm.stats.diagnostic.acorr_ljungbox(residual, lags=20, boxpierce=False,return_df=True)

# %%
statistic_lb
# Out:
#       lb_stat  lb_pvalue
# 1    0.013523   0.907423
# 2    5.799406   0.055040
# 3    6.222139   0.101289
# 4    6.266493   0.180111
# 5    6.413746   0.268015
# 6    6.474554   0.372178
# 7    8.097402   0.324084
# 8    8.941022   0.347296
# 9    9.038705   0.433709
# 10   9.530620   0.482591
# 11   9.643858   0.562678
# 12  17.230730   0.141122
# 13  19.041270   0.121830
# 14  19.591688   0.143549
# 15  21.284792   0.127974
# 16  21.290571   0.167610
# 17  23.035536   0.148097
# 18  23.295039   0.179506
# 19  24.801457   0.167182
# 20  28.284937   0.102824

# %% [markdown]
# La prueba puede ser consumidora de tiempo y seleccionamos un subconjunto de los residuos. Aquí simplemente establecemos el número máximo de rezagos en 20. En los resultados a continuación, encontramos que los valores p son todos mayores que 0.01, lo que indica que NO podemos rechazar la hipótesis nula con un nivel de confianza del 99% para cualquier rezago. Esto es evidencia sólida de que el modelo no está subajustado y se necesitan más rezagos en nuestro modelo. A diferencia de un modelo autorregresivo, aumentar el número de rezagos en la RNN no aumenta el número de pesos. Por lo tanto, no hay peligro de sobreajuste al aumentar el rezago, aunque habrá un aumento en el tiempo de entrenamiento.
