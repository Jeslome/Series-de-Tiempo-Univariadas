# %% [markdown]
# <center>
#     <h1 style="color: #3498db;">Aplicación de Redes Neuronales Recurrentes para la serie del Atleta Colombiano Iván</h1>
# </center>

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Librerías Necesarias</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import tensorflow as tf
from datetime import timedelta

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, TimeSeriesSplit, GridSearchCV

import tensorflow.keras as keras

#from keras import initializers
#from tensorflow.keras.layers import Dense, Layer, LSTM, GRU, SimpleRNN, RNN
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.models import load_model
#from tensorflow.keras.regularizers import l1, l2
#from tensorflow.keras.callbacks import EarlyStopping
#from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %%
# %matplotlib inline

# %%
import gc
gc.collect()
# Out:
# 30

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Descripción de la serie</h2>

# %%
ruta = r"C:\Users\Lenovo\Desktop\shyni\Serie_Ivan.xlsx"

# Lee el archivo Excel
df = pd.read_excel(ruta,index_col=0)
# Muestra las primeras filas del DataFrame
print(df.head())
df.size
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# 268

# %%
df.index = pd.to_datetime(df.index, infer_datetime_format=True)

# %%
df
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8
#
# [268 rows x 1 columns]

# %%
nof_missing_values = sum(np.isnan(df['KMS']))

print(nof_missing_values, 'observations are missing.')
print('This is {:.3f}% of the total.'.format(nof_missing_values*100/len(df)))
# Out:
# 0 observations are missing.
# This is 0.000% of the total.

# %%
df = df.fillna(method="backfill")
nof_missing_values = sum(np.isnan(df['KMS']))

print('Now', nof_missing_values, 'observations are missing.')
# Out:
# Now 0 observations are missing.

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">RNN Regression</h2>

# %%
use_features = ['KMS'] # continuous input
target = ['KMS'] # continuous output
n_steps_ahead = 1 # forecasting horizon

# %%
plt.plot(df['KMS'])

# %%
df.dropna(inplace=True)
print(df)
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8
#
# [268 rows x 1 columns]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Estacionariedad</h2>

# %% [markdown]
# Es esencial determinar si la serie de tiempo es "estacionaria". Informalmente, la estacionariedad ocurre cuando la autocovarianza es independiente del tiempo. No establecer la estacionariedad casi con certeza conducirá a una mala interpretación de la identificación del modelo y las pruebas diagnósticas. Además, la estacionariedad es decisiva para caracterizar el problema de predicción y determinar si se debe usar una arquitectura más avanzada. En particular, podemos esperar que una RNN simple funcione mal si los datos no son estacionarios, ya que la RNN presenta una autocovarianza fija.
#
# Realizamos una prueba de Dickey-Fuller Aumentada para establecer la estacionariedad bajo el supuesto de que la serie de tiempo tiene un sesgo constante pero no presenta una tendencia temporal. En otras palabras, asumimos que la serie de tiempo ya está des-trendida.
#
# Si la prueba de estacionariedad falla, incluso después de des-trender la serie de tiempo, entonces un recurso potencial es simplemente tomar diferencias de la serie de tiempo y predecir $\Delta y_t$.

# %%
sample = df['KMS'][:268]
adf, p, usedlag, nobs, cvs, aic = sm.tsa.stattools.adfuller(sample)

# %%
adf_results_string = 'ADF: {}\np-value: {},\nN: {}, \ncritical values: {}'
print(adf_results_string.format(adf, p, nobs, cvs))
# Out:
# ADF: -8.294440147260046
# p-value: 4.1767430606472077e-13,
# N: 266,
# critical values: {'1%': -3.455175292841607, '5%': -2.8724677563219485, '10%': -2.57259315846006}

# %% [markdown]
# Aquí rechazamos la hipótesis nula ya que el valor p es menor que 0.01, por lo tanto,  podemos rechazar la prueba al nivel de confianza del 99%. Esto sugiere que la serie temporal  es **estacionaria**.

# %%
pacf = sm.tsa.stattools.pacf(df[use_features], nlags=52)
print(pacf)
# Out:
# [ 1.          0.35982968  0.1112808  -0.05356433  0.04189731 -0.03024228
#  -0.03798688 -0.00208805 -0.01438159  0.06928826  0.01587568 -0.11641937
#  -0.04475874 -0.02741998  0.01813617  0.047017    0.0398394   0.02744579
#  -0.04711411  0.01880179 -0.03288715  0.04010612 -0.04665097 -0.00705715
#  -0.06939977 -0.08739706 -0.12940267 -0.04402874  0.12694111  0.03792325
#   0.10913632 -0.05427822  0.02069914  0.04766867 -0.01439542  0.11169568
#  -0.01045524  0.09871045 -0.12141682  0.07815533 -0.09998191 -0.07975051
#   0.01579923  0.0805939   0.04519596  0.07646898  0.03325565 -0.09312151
#   0.02436844  0.10388561  0.0086983   0.00908146  0.14322692]

# %%
T = len(df[use_features])
sig_test = lambda tau_h: np.abs(tau_h) > 2.58/np.sqrt(T)
df[use_features].head()
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5

# %%
for i in range(len(pacf)):
    if sig_test(pacf[i]) == False:
        n_steps = i - 1
        n_steps=n_steps
        print('n_steps set to', n_steps)
        break
# Out:
# n_steps set to 1

# %%
 n_steps= n_steps+1

# %%
plt.plot(pacf, label='pacf')
plt.plot([2.58/np.sqrt(T)]*52, label='99% confidence interval (upper)')
plt.plot([-2.58/np.sqrt(T)]*52, label='99% confidence interval (lower)')
plt.xlabel('number of lags')
plt.legend();

# %% [markdown]
# Por lo que para este caso el número de retardos significativo es de **1** pero tomaremos 2.

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;"> Dividiendo la serie temporal en conjuntos de entrenamiento y prueba</h2>

# %%
train_weight = 0.80
split = int(len(df) * train_weight)

df_train = df[use_features].iloc[:split]
df_test = df[use_features].iloc[split:]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Estandarización de los datos</h2>

# %% [markdown]
# La estandarización de los datos es importante para evitar posibles dificultades de escala en el ajuste del modelo. Cuando hay más de una característica (covariable), la estandarización evita que una característica domine sobre otra debido a escalas dispares.
# Para evitar introducir un sesgo de anticipación en la predicción, debemos reescalar los datos de entrenamiento sin conocimiento del conjunto de prueba. Por lo tanto, simplemente estandarizaremos el conjunto de entrenamiento utilizando la media y la desviación estándar del conjunto de entrenamiento y no de toda la serie temporal. Además, para evitar introducir un sesgo sistemático en el conjunto de prueba, utilizamos la misma normalización para el conjunto de prueba: la media y la desviación estándar del conjunto de entrenamiento se utilizan para normalizar el conjunto de prueba.

# %%
mu = float(df_train.mean())
sigma = float(df_train.std())
print(sigma)
print(mu)
stdize_input = lambda x: (x - mu) / sigma

df_train = df_train.apply(stdize_input)
df_test = df_test.apply(stdize_input)
print(df_train)
print(df_test)
# Out:
# 48.97102603165779
# 124.08225233644858
#                  KMS
# DATE
# 2018-12-31 -2.180519
# 2019-01-07 -0.769481
# 2019-01-14 -0.342698
# 2019-01-21  0.796752
# 2019-01-28  0.600717
# ...              ...
# 2023-01-02  1.550258
# 2023-01-09  1.517586
# 2023-01-16  1.164316
# 2023-01-23  1.621729
# 2023-01-30  0.574171
#
# [214 rows x 1 columns]
#                  KMS
# DATE
# 2023-02-06  0.472070
# 2023-02-13 -1.034944
# 2023-02-20 -1.453559
# 2023-02-27 -0.992061
# 2023-03-06  0.192313
# 2023-03-13  1.123475
# 2023-03-20 -0.363118
# 2023-03-27  1.774881
# 2023-04-03 -1.073742
# 2023-04-10 -0.532606
# 2023-04-17  1.025458
# 2023-04-24  1.182694
# 2023-05-01  1.111223
# 2023-05-08  0.823298
# 2023-05-15 -0.671463
# 2023-05-22  0.118800
# 2023-05-29  1.152064
# 2023-06-05  0.986660
# 2023-06-12  0.904979
# 2023-06-19  0.200481
# 2023-06-26  0.627264
# 2023-07-03 -1.059448
# 2023-07-10  0.958072
# 2023-07-17 -1.412718
# 2023-07-24 -0.330445
# 2023-07-31 -2.262200
# 2023-08-07  1.564553
# 2023-08-14 -0.030268
# 2023-08-21  1.364434
# 2023-08-28  1.270501
# 2023-09-04  1.262333
# 2023-09-11 -0.350866
# 2023-09-18  0.680356
# 2023-09-25 -1.814997
# 2023-10-02  0.337296
# 2023-10-09  1.007080
# 2023-10-16 -0.173210
# 2023-10-23  0.131052
# 2023-10-30 -1.147255
# 2023-11-06  0.465944
# 2023-11-13 -0.011890
# 2023-11-20 -0.879750
# 2023-11-27  0.463902
# 2023-12-04  0.398557
# 2023-12-11  1.321552
# 2023-12-18  1.593141
# 2023-12-25  0.043245
# 2024-01-01  1.678906
# 2024-01-08  1.774881
# 2024-01-15  1.595183
# 2024-01-22  1.568637
# 2024-01-29  0.747743
# 2024-02-05  0.237237
# 2024-02-12 -0.046604

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Formato datos para la RNNs</h2>

# %% [markdown]
# TensorFlow utiliza tensores para representar los datos. Para realizar el aprendizaje de secuencias, la serie temporal de variables debe transformarse en una serie de subsecuencias superpuestas.

# %%
def get_lagged_features(df, n_steps, n_steps_ahead):
    """
    df: pandas DataFrame of time series to be lagged
    n_steps: number of lags, i.e. sequence length
    n_steps_ahead: forecasting horizon
    """
    lag_list = []
    
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append(df.shift(lag))
    lag_array = np.dstack([i[n_steps+n_steps_ahead-1:] for i in lag_list])
    # We swap the last two dimensions so each slice along the first dimension
    # is the same shape as the corresponding segment of the input time series 
    lag_array = np.swapaxes(lag_array, 1, -1)
    return lag_array

# %%
n_steps_ahead
# Out:
# 1

# %% [markdown]
# Primero transformaremos los datos de entrada y salida del entrenamiento

# %%
x_train = get_lagged_features(df_train, n_steps, n_steps_ahead)
y_train =  df_train.values[n_steps + n_steps_ahead - 1:]
y_train_timestamps = df_train.index[n_steps + n_steps_ahead - 1:]

x_test = get_lagged_features(df_test, n_steps, n_steps_ahead)
y_test =  df_test.values[n_steps + n_steps_ahead - 1:]
y_test_timestamps = df_test.index[n_steps + n_steps_ahead - 1:]

# %%
print(y_train_timestamps)
# Out:
# DatetimeIndex(['2019-01-14', '2019-01-21', '2019-01-28', '2019-02-04',
#                '2019-02-11', '2019-02-18', '2019-02-25', '2019-03-04',
#                '2019-03-11', '2019-03-18',
#                ...
#                '2022-11-28', '2022-12-05', '2022-12-12', '2022-12-19',
#                '2022-12-26', '2023-01-02', '2023-01-09', '2023-01-16',
#                '2023-01-23', '2023-01-30'],
#               dtype='datetime64[ns]', name='DATE', length=212, freq=None)

# %%
print(y_test_timestamps)
# Out:
# DatetimeIndex(['2023-02-20', '2023-02-27', '2023-03-06', '2023-03-13',
#                '2023-03-20', '2023-03-27', '2023-04-03', '2023-04-10',
#                '2023-04-17', '2023-04-24', '2023-05-01', '2023-05-08',
#                '2023-05-15', '2023-05-22', '2023-05-29', '2023-06-05',
#                '2023-06-12', '2023-06-19', '2023-06-26', '2023-07-03',
#                '2023-07-10', '2023-07-17', '2023-07-24', '2023-07-31',
#                '2023-08-07', '2023-08-14', '2023-08-21', '2023-08-28',
#                '2023-09-04', '2023-09-11', '2023-09-18', '2023-09-25',
#                '2023-10-02', '2023-10-09', '2023-10-16', '2023-10-23',
#                '2023-10-30', '2023-11-06', '2023-11-13', '2023-11-20',
#                '2023-11-27', '2023-12-04', '2023-12-11', '2023-12-18',
#                '2023-12-25', '2024-01-01', '2024-01-08', '2024-01-15',
#                '2024-01-22', '2024-01-29', '2024-02-05', '2024-02-12'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
print([tensor.shape for tensor in (x_train, y_train, x_test, y_test)])
# Out:
# [(212, 2, 1), (212, 1), (52, 2, 1), (52, 1)]

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Especificación del modelo</h2>

# %% [markdown]
# **Red Neuronal Recurrente**

# %%
def SimpleRNN_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.SimpleRNN(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True, stateful=False))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.SimpleRNN:** Agrega una capa SimpleRNN al modelo.
# - **n_units:** Número de unidades/neuronas en la capa SimpleRNN.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa SimpleRNN para acelerar el entrenamiento si es posible.
# - **stateful=False:** No mantiene estados persistentes entre muestras.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %% [markdown]
# **Red Neuronal GRU**

# %%
def GRU_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.GRU(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.GRU:** Agrega una capa GRU al modelo.
# - **n_units:** Número de unidades/neuronas en la capa GRU.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa GRU para acelerar el entrenamiento si es posible.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %% [markdown]
# **Red Neuronal LSTM**

# %%
def LSTM_(n_units = 10, l1_reg=0, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.LSTM(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.l1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True)) 
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.l1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# - **keras.layers.LSTM:** Agrega una capa LSTM al modelo.
# - **n_units:** Número de unidades/neuronas en la capa LSTM.
# - **activation='tanh':** Función de activación tangente hiperbólica.
# - **kernel_initializer, bias_initializer, recurrent_initializer:** Inicializadores de pesos y sesgos para los pesos y la parte recurrente de la capa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa.
# - **input_shape:** Forma de entrada del modelo, basada en las dimensiones de los datos de entrenamiento x_train.
# - **unroll=True:** Desenrolla la capa LSTM para acelerar el entrenamiento si es posible.
# - **1:** Una sola neurona en la capa densa para problemas de regresión.
# - **kernel_initializer, bias_initializer:** Inicializadores de pesos y sesgos para la capa densa.
# - **kernel_regularizer:** Regularización L1 aplicada a los pesos de la capa densa.
# - **loss='mean_squared_error':** Función de pérdida de error cuadrático medio para problemas de regresión.
# - **optimizer='adam':** Optimizador Adam, un algoritmo de optimización eficiente para el entrenamiento de redes neuronales.

# %%
max_epochs = 20 #Dejar mil
batch_size = 30

# %%
es = keras.callbacks.EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10, min_delta=1e-7, restore_best_weights=True)

# %%
params = {
    'rnn': {
        'model': None, 'function': SimpleRNN_, 'l1_reg': 0.0, 'H': 20, 
        'color': 'blue', 'label':'RNN'}, 
    'gru': {
        'model': None, 'function':GRU_,'l1_reg': 0.0, 'H': 10, 
        'color': 'orange', 'label': 'GRU'},
    'lstm': {
        'model': None, 'function': LSTM_,'l1_reg': 0.0, 'H': 10, 
        'color':'red', 'label': 'LSTM'}
}

# %%
params
# Out:
# {'rnn': {'model': None,
#   'function': <function __main__.SimpleRNN_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 20,
#   'color': 'blue',
#   'label': 'RNN'},
#  'gru': {'model': None,
#   'function': <function __main__.GRU_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 10,
#   'color': 'orange',
#   'label': 'GRU'},
#  'lstm': {'model': None,
#   'function': <function __main__.LSTM_(n_units=10, l1_reg=0, seed=0)>,
#   'l1_reg': 0.0,
#   'H': 10,
#   'color': 'red',
#   'label': 'LSTM'}}

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Cargando modelos preentrenados</h2>
#
# Entrenar los modelos lleva varias horas. Para ahorrar tiempo, puedes cargar los modelos ya ajustados en su lugar:

# %%
do_training = True # Set to True if you wish to train your own models

# %%
params.keys()
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
if do_training is False:
     for key in params.keys():
        params[key]['model']=keras.models.load_model('RNNs-Ivan-SAVED-' + key + '.hdf5')

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Validación cruzada</h2>

# %% [markdown]
# La celda siguiente realiza una búsqueda en cuadrícula para optimizar n_units y l1_reg para cada uno de los modelos utilizando los datos de entrenamiento.
#
# Los resultados se validan cruzadamente para evitar el sobreajuste. Se utiliza la función TimeSeriesSplit de Scikit-Learn para dividir los datos en 5 pares de conjuntos de entrenamiento y prueba, donde los datos de prueba siempre están adelante en el tiempo respecto a los datos de entrenamiento.

# %%
cross_val = True # WARNING: Changing this to True will take many hours to run

if do_training and cross_val:
    n_units = [5, 10, 20,30]
    l1_reg = [0, 0.001, 0.01, 0.1]
    
    # A dictionary containing a list of values to be iterated through
    # for each parameter of the model included in the search
    param_grid = {'n_units': n_units, 'l1_reg': l1_reg}
    
    # In the kth split, TimeSeriesSplit returns first k folds 
    # as training set and the (k+1)th fold as test set.
    tscv = TimeSeriesSplit(n_splits = 5)
    
    # A grid search is performed for each of the models, and the parameter set which
    # performs best over all the cross-validation splits is saved in the `params` dictionary
    for key in params.keys():
        print('Performing cross-validation. Model:', key)
        model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=params[key]['function'], epochs=max_epochs, 
                               batch_size=batch_size, verbose=2)
        #from scikeras.wrappers import KerasClassifier, KerasRegressor
        grid = GridSearchCV(estimator=model, param_grid=param_grid, 
                            cv=tscv, n_jobs=1, verbose=2)
        grid_result = grid.fit(x_train, y_train, callbacks=[es])
        print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
        
        means = grid_result.cv_results_['mean_test_score']
        stds = grid_result.cv_results_['std_test_score']
        params_ = grid_result.cv_results_['params']
        for mean, stdev, param_ in zip(means, stds, params_):
            print("%f (%f) with %r" % (mean, stdev, param_))
            
        params[key]['H'] = grid_result.best_params_['n_units']
        params[key]['l1_reg']= grid_result.best_params_['l1_reg']
# Out:
# Performing cross-validation. Model: rnn
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2224\2699852436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=params[key]['function'], epochs=max_epochs,
# Epoch 1/20
# 2/2 - 3s - loss: 1.2608 - 3s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 1.2507 - 22ms/epoch - 11ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 1.2372 - 15ms/epoch - 7ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 1.2287 - 22ms/epoch - 11ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.2198 - 27ms/epoch - 13ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.2106 - 16ms/epoch - 8ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.2013 - 22ms/epoch - 11ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.1930 - 17ms/epoch - 8ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.1845 - 17ms/epoch - 9ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.1755 - 33ms/epoch - 17ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.1683 - 18ms/epoch - 9ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.1610 - 28ms/epoch - 14ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.1530 - 27ms/epoch - 13ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.1457 - 17ms/epoch - 9ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.1384 - 16ms/epoch - 8ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.1319 - 30ms/epoch - 15ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.1250 - 20ms/epoch - 10ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.1180 - 15ms/epoch - 8ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.1115 - 22ms/epoch - 11ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.1044 - 18ms/epoch - 9ms/step
# 2/2 - 1s - loss: 0.5733 - 742ms/epoch - 371ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   5.6s
# Epoch 1/20
# 3/3 - 5s - loss: 0.9632 - 5s/epoch - 2s/step
# Epoch 2/20
# 3/3 - 0s - loss: 0.9494 - 20ms/epoch - 7ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 0.9362 - 22ms/epoch - 7ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 0.9241 - 27ms/epoch - 9ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 0.9116 - 20ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 0.9006 - 49ms/epoch - 16ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 0.8895 - 20ms/epoch - 7ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 0.8777 - 24ms/epoch - 8ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 0.8678 - 34ms/epoch - 11ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 0.8591 - 21ms/epoch - 7ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 0.8471 - 69ms/epoch - 23ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 0.8388 - 27ms/epoch - 9ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 0.8292 - 21ms/epoch - 7ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 0.8212 - 26ms/epoch - 9ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 0.8126 - 23ms/epoch - 8ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 0.8053 - 65ms/epoch - 22ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 0.7990 - 21ms/epoch - 7ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 0.7906 - 20ms/epoch - 7ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 0.7840 - 31ms/epoch - 10ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 0.7778 - 23ms/epoch - 8ms/step
# 2/2 - 2s - loss: 1.1957 - 2s/epoch - 1s/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   8.5s
# Epoch 1/20
# 4/4 - 5s - loss: 1.0943 - 5s/epoch - 1s/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.0780 - 73ms/epoch - 18ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.0611 - 65ms/epoch - 16ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.0452 - 27ms/epoch - 7ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.0306 - 27ms/epoch - 7ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.0162 - 51ms/epoch - 13ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.0019 - 49ms/epoch - 12ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 0.9890 - 52ms/epoch - 13ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 0.9749 - 28ms/epoch - 7ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 0.9629 - 56ms/epoch - 14ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 0.9526 - 58ms/epoch - 15ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 0.9425 - 47ms/epoch - 12ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 0.9312 - 35ms/epoch - 9ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 0.9213 - 27ms/epoch - 7ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 0.9119 - 43ms/epoch - 11ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 0.9037 - 36ms/epoch - 9ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 0.8958 - 33ms/epoch - 8ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 0.8878 - 26ms/epoch - 7ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 0.8808 - 34ms/epoch - 9ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 0.8735 - 40ms/epoch - 10ms/step
# 2/2 - 1s - loss: 1.0425 - 715ms/epoch - 358ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   7.3s
# Epoch 1/20
# 5/5 - 5s - loss: 1.1319 - 5s/epoch - 967ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.1110 - 34ms/epoch - 7ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.0895 - 42ms/epoch - 8ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.0721 - 38ms/epoch - 8ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.0521 - 31ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.0359 - 32ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.0207 - 28ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.0036 - 30ms/epoch - 6ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 0.9896 - 29ms/epoch - 6ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 0.9770 - 30ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 0.9643 - 28ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 0.9532 - 27ms/epoch - 5ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 0.9419 - 28ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 0.9321 - 33ms/epoch - 7ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 0.9217 - 145ms/epoch - 29ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 0.9144 - 57ms/epoch - 11ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 0.9058 - 27ms/epoch - 5ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 0.8984 - 28ms/epoch - 6ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 0.8906 - 31ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 0.8848 - 37ms/epoch - 7ms/step
# 2/2 - 1s - loss: 0.9279 - 766ms/epoch - 383ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   7.3s
# Epoch 1/20
# 6/6 - 5s - loss: 1.1405 - 5s/epoch - 844ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.1138 - 46ms/epoch - 8ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.0901 - 34ms/epoch - 6ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.0707 - 43ms/epoch - 7ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.0474 - 35ms/epoch - 6ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.0294 - 35ms/epoch - 6ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.0120 - 38ms/epoch - 6ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 0.9965 - 61ms/epoch - 10ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 0.9807 - 32ms/epoch - 5ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 0.9648 - 31ms/epoch - 5ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 0.9538 - 35ms/epoch - 6ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 0.9417 - 39ms/epoch - 6ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 0.9302 - 34ms/epoch - 6ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 0.9202 - 33ms/epoch - 6ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 0.9110 - 35ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 0.9027 - 30ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 0.8948 - 29ms/epoch - 5ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 0.8869 - 49ms/epoch - 8ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 0.8799 - 34ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 0.8733 - 34ms/epoch - 6ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021C03C12DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 1s - loss: 1.0188 - 806ms/epoch - 403ms/step
# [CV] END ................................l1_reg=0, n_units=5; total time=   7.4s
# Epoch 1/20
# 2/2 - 5s - loss: 1.8540 - 5s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 1.8295 - 17ms/epoch - 9ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 1.8087 - 16ms/epoch - 8ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 1.7880 - 17ms/epoch - 8ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.7660 - 17ms/epoch - 9ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.7458 - 17ms/epoch - 8ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.7275 - 16ms/epoch - 8ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.7069 - 16ms/epoch - 8ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.6898 - 17ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.6695 - 17ms/epoch - 8ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.6540 - 17ms/epoch - 8ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.6349 - 18ms/epoch - 9ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.6179 - 16ms/epoch - 8ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.6009 - 17ms/epoch - 8ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.5842 - 18ms/epoch - 9ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.5667 - 16ms/epoch - 8ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.5496 - 17ms/epoch - 8ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.5336 - 18ms/epoch - 9ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.5176 - 17ms/epoch - 8ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.5019 - 17ms/epoch - 8ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021C7F7D4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 1s - loss: 0.7504 - 687ms/epoch - 344ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   6.8s
# Epoch 1/20
# 3/3 - 4s - loss: 1.4260 - 4s/epoch - 1s/step
# Epoch 2/20
# 3/3 - 0s - loss: 1.3853 - 21ms/epoch - 7ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 1.3513 - 21ms/epoch - 7ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 1.3188 - 21ms/epoch - 7ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 1.2907 - 21ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 1.2623 - 19ms/epoch - 6ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 1.2342 - 16ms/epoch - 5ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 1.2131 - 16ms/epoch - 5ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 1.1874 - 16ms/epoch - 5ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 1.1653 - 16ms/epoch - 5ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 1.1467 - 16ms/epoch - 5ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 1.1277 - 16ms/epoch - 5ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 1.1094 - 16ms/epoch - 5ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 1.0916 - 31ms/epoch - 10ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 1.0741 - 16ms/epoch - 5ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.0580 - 16ms/epoch - 5ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.0431 - 31ms/epoch - 10ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.0289 - 16ms/epoch - 5ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.0152 - 31ms/epoch - 10ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 0.9997 - 16ms/epoch - 5ms/step
# 2/2 - 1s - loss: 1.4524 - 594ms/epoch - 297ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   5.2s
# Epoch 1/20
# 4/4 - 3s - loss: 1.5694 - 3s/epoch - 840ms/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.5179 - 16ms/epoch - 4ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.4776 - 16ms/epoch - 4ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.4377 - 16ms/epoch - 4ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.4019 - 16ms/epoch - 4ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.3698 - 31ms/epoch - 8ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.3389 - 31ms/epoch - 8ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 1.3082 - 31ms/epoch - 8ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 1.2815 - 16ms/epoch - 4ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 1.2546 - 16ms/epoch - 4ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 1.2326 - 16ms/epoch - 4ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 1.2096 - 31ms/epoch - 8ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 1.1874 - 38ms/epoch - 9ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 1.1654 - 24ms/epoch - 6ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 1.1455 - 36ms/epoch - 9ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 1.1265 - 26ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 1.1071 - 25ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 1.0901 - 25ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.0721 - 29ms/epoch - 7ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.0570 - 23ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.1983 - 584ms/epoch - 292ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   5.2s
# Epoch 1/20
# 5/5 - 4s - loss: 1.6104 - 4s/epoch - 849ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.5481 - 31ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.4959 - 16ms/epoch - 3ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.4521 - 16ms/epoch - 3ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.4073 - 32ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.3695 - 22ms/epoch - 4ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.3312 - 31ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.2970 - 58ms/epoch - 12ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.2659 - 42ms/epoch - 8ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 1.2347 - 31ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 1.2089 - 31ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 1.1800 - 29ms/epoch - 6ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 1.1544 - 31ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 1.1329 - 30ms/epoch - 6ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 1.1088 - 28ms/epoch - 6ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 1.0896 - 31ms/epoch - 6ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.0708 - 28ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.0520 - 34ms/epoch - 7ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.0361 - 30ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.0193 - 33ms/epoch - 7ms/step
# 2/2 - 2s - loss: 1.1102 - 2s/epoch - 755ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   7.2s
# Epoch 1/20
# 6/6 - 6s - loss: 1.6269 - 6s/epoch - 1s/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.5577 - 37ms/epoch - 6ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.5027 - 36ms/epoch - 6ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.4494 - 40ms/epoch - 7ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.3986 - 42ms/epoch - 7ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.3538 - 36ms/epoch - 6ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.3148 - 42ms/epoch - 7ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.2790 - 39ms/epoch - 7ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 1.2402 - 41ms/epoch - 7ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 1.2090 - 36ms/epoch - 6ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 1.1775 - 56ms/epoch - 9ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 1.1490 - 39ms/epoch - 7ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 1.1221 - 35ms/epoch - 6ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.0980 - 86ms/epoch - 14ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.0754 - 38ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.0545 - 35ms/epoch - 6ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.0358 - 38ms/epoch - 6ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.0165 - 34ms/epoch - 6ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.0006 - 36ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 0.9849 - 46ms/epoch - 8ms/step
# 2/2 - 1s - loss: 1.0951 - 832ms/epoch - 416ms/step
# [CV] END ...............................l1_reg=0, n_units=10; total time=   9.0s
# Epoch 1/20
# 2/2 - 6s - loss: 2.1087 - 6s/epoch - 3s/step
# Epoch 2/20
# 2/2 - 0s - loss: 2.0648 - 16ms/epoch - 8ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 2.0305 - 17ms/epoch - 8ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 1.9940 - 17ms/epoch - 8ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.9609 - 19ms/epoch - 9ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.9288 - 18ms/epoch - 9ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.9001 - 18ms/epoch - 9ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.8692 - 18ms/epoch - 9ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.8405 - 19ms/epoch - 9ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.8141 - 16ms/epoch - 8ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.7852 - 18ms/epoch - 9ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.7586 - 17ms/epoch - 8ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.7292 - 11ms/epoch - 6ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.7060 - 32ms/epoch - 16ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.6804 - 12ms/epoch - 6ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.6539 - 89ms/epoch - 45ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.6315 - 17ms/epoch - 9ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.6095 - 19ms/epoch - 9ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.5845 - 19ms/epoch - 10ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.5645 - 32ms/epoch - 16ms/step
# 2/2 - 1s - loss: 0.7004 - 648ms/epoch - 324ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   7.8s
# Epoch 1/20
# 3/3 - 5s - loss: 1.6375 - 5s/epoch - 2s/step
# Epoch 2/20
# 3/3 - 0s - loss: 1.5635 - 22ms/epoch - 7ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 1.5014 - 20ms/epoch - 7ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 1.4423 - 21ms/epoch - 7ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 1.3983 - 20ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 1.3571 - 21ms/epoch - 7ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 1.3144 - 23ms/epoch - 8ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 1.2838 - 20ms/epoch - 7ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 1.2528 - 20ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 1.2204 - 21ms/epoch - 7ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 1.1936 - 21ms/epoch - 7ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 1.1677 - 24ms/epoch - 8ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 1.1372 - 14ms/epoch - 5ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 1.1148 - 16ms/epoch - 5ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 1.0879 - 31ms/epoch - 10ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.0632 - 22ms/epoch - 7ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.0430 - 16ms/epoch - 5ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.0220 - 31ms/epoch - 10ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.0036 - 16ms/epoch - 5ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 0.9837 - 16ms/epoch - 5ms/step
# 2/2 - 1s - loss: 1.5141 - 675ms/epoch - 338ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   6.9s
# Epoch 1/20
# 4/4 - 5s - loss: 1.8534 - 5s/epoch - 1s/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.7476 - 23ms/epoch - 6ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.6719 - 24ms/epoch - 6ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.6050 - 27ms/epoch - 7ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.5476 - 27ms/epoch - 7ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.5005 - 24ms/epoch - 6ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.4507 - 27ms/epoch - 7ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 1.4031 - 26ms/epoch - 7ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 1.3631 - 25ms/epoch - 6ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 1.3297 - 24ms/epoch - 6ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 1.2916 - 25ms/epoch - 6ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 1.2560 - 31ms/epoch - 8ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 1.2245 - 25ms/epoch - 6ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 1.1930 - 34ms/epoch - 9ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 1.1662 - 33ms/epoch - 8ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 1.1417 - 24ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 1.1144 - 25ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 1.0926 - 24ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.0729 - 31ms/epoch - 8ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.0501 - 28ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.1884 - 610ms/epoch - 305ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   6.8s
# Epoch 1/20
# 5/5 - 4s - loss: 1.9209 - 4s/epoch - 736ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.7852 - 55ms/epoch - 11ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.6924 - 42ms/epoch - 8ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.6139 - 31ms/epoch - 6ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.5520 - 31ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.4930 - 32ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.4361 - 32ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.3856 - 46ms/epoch - 9ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.3408 - 42ms/epoch - 8ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 1.2945 - 31ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 1.2539 - 31ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 1.2151 - 47ms/epoch - 9ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 1.1829 - 19ms/epoch - 4ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 1.1495 - 16ms/epoch - 3ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 1.1217 - 31ms/epoch - 6ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 1.0921 - 61ms/epoch - 12ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.0691 - 37ms/epoch - 7ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.0479 - 31ms/epoch - 6ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.0254 - 31ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.0072 - 40ms/epoch - 8ms/step
# 2/2 - 1s - loss: 1.0936 - 686ms/epoch - 343ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   5.7s
# Epoch 1/20
# 6/6 - 5s - loss: 1.9179 - 5s/epoch - 785ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.7868 - 47ms/epoch - 8ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.6756 - 51ms/epoch - 9ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.5927 - 50ms/epoch - 8ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.5221 - 55ms/epoch - 9ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.4546 - 58ms/epoch - 10ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.3970 - 50ms/epoch - 8ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.3315 - 33ms/epoch - 6ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 1.2815 - 32ms/epoch - 5ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 1.2375 - 45ms/epoch - 8ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 1.1958 - 32ms/epoch - 5ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 1.1558 - 31ms/epoch - 5ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 1.1232 - 49ms/epoch - 8ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.0920 - 40ms/epoch - 7ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.0627 - 35ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.0383 - 31ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.0159 - 46ms/epoch - 8ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 0.9963 - 32ms/epoch - 5ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 0.9775 - 47ms/epoch - 8ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 0.9584 - 41ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.0588 - 956ms/epoch - 478ms/step
# [CV] END ...............................l1_reg=0, n_units=20; total time=   7.3s
# Epoch 1/20
# 2/2 - 8s - loss: 2.7489 - 8s/epoch - 4s/step
# Epoch 2/20
# 2/2 - 0s - loss: 2.6618 - 16ms/epoch - 8ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 2.6010 - 20ms/epoch - 10ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 2.5338 - 18ms/epoch - 9ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 2.4829 - 20ms/epoch - 10ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 2.4276 - 18ms/epoch - 9ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 2.3825 - 17ms/epoch - 9ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 2.3301 - 18ms/epoch - 9ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 2.2802 - 17ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 2.2341 - 20ms/epoch - 10ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 2.1847 - 24ms/epoch - 12ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 2.1425 - 21ms/epoch - 10ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 2.0965 - 17ms/epoch - 8ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 2.0520 - 20ms/epoch - 10ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 2.0164 - 18ms/epoch - 9ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.9702 - 23ms/epoch - 12ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.9378 - 17ms/epoch - 8ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.8951 - 18ms/epoch - 9ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.8607 - 17ms/epoch - 8ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.8296 - 19ms/epoch - 10ms/step
# 2/2 - 1s - loss: 0.8679 - 816ms/epoch - 408ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   9.9s
# Epoch 1/20
# 3/3 - 6s - loss: 2.1655 - 6s/epoch - 2s/step
# Epoch 2/20
# 3/3 - 0s - loss: 2.0078 - 34ms/epoch - 11ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 1.8973 - 22ms/epoch - 7ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 1.8172 - 38ms/epoch - 13ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 1.7501 - 21ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 1.7002 - 27ms/epoch - 9ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 1.6447 - 21ms/epoch - 7ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 1.5951 - 28ms/epoch - 9ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 1.5436 - 22ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 1.4972 - 26ms/epoch - 9ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 1.4532 - 26ms/epoch - 9ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 1.4044 - 53ms/epoch - 18ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 1.3659 - 22ms/epoch - 7ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 1.3261 - 25ms/epoch - 8ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 1.2923 - 29ms/epoch - 10ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.2595 - 27ms/epoch - 9ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.2305 - 23ms/epoch - 8ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.1939 - 27ms/epoch - 9ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.1662 - 28ms/epoch - 9ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 1.1401 - 28ms/epoch - 9ms/step
# 2/2 - 1s - loss: 1.7350 - 775ms/epoch - 388ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   8.3s
# Epoch 1/20
# 4/4 - 6s - loss: 2.4583 - 6s/epoch - 2s/step
# Epoch 2/20
# 4/4 - 0s - loss: 2.2391 - 48ms/epoch - 12ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 2.1075 - 38ms/epoch - 10ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 2.0245 - 46ms/epoch - 12ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.9487 - 25ms/epoch - 6ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.8635 - 29ms/epoch - 7ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.7801 - 27ms/epoch - 7ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 1.7106 - 29ms/epoch - 7ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 1.6404 - 34ms/epoch - 8ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 1.5730 - 32ms/epoch - 8ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 1.5266 - 29ms/epoch - 7ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 1.4689 - 27ms/epoch - 7ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 1.4162 - 38ms/epoch - 9ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 1.3731 - 31ms/epoch - 8ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 1.3349 - 26ms/epoch - 6ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 1.2892 - 29ms/epoch - 7ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 1.2543 - 33ms/epoch - 8ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 1.2202 - 39ms/epoch - 10ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.1885 - 27ms/epoch - 7ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.1582 - 26ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.2898 - 901ms/epoch - 451ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   8.5s
# Epoch 1/20
# 5/5 - 5s - loss: 2.5673 - 5s/epoch - 1s/step
# Epoch 2/20
# 5/5 - 0s - loss: 2.2823 - 31ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 2.1337 - 31ms/epoch - 6ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 2.0187 - 31ms/epoch - 6ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.9247 - 31ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.8238 - 31ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.7305 - 31ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.6426 - 16ms/epoch - 3ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.5704 - 31ms/epoch - 6ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 1.5040 - 31ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 1.4403 - 31ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 1.3854 - 31ms/epoch - 6ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 1.3309 - 31ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 1.2847 - 16ms/epoch - 3ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 1.2439 - 31ms/epoch - 6ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 1.2057 - 47ms/epoch - 9ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.1736 - 31ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.1387 - 16ms/epoch - 3ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.1103 - 31ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.0815 - 31ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.1822 - 797ms/epoch - 398ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   7.4s
# Epoch 1/20
# 6/6 - 5s - loss: 2.5733 - 5s/epoch - 842ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 2.2854 - 42ms/epoch - 7ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 2.1055 - 36ms/epoch - 6ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.9814 - 41ms/epoch - 7ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.8619 - 39ms/epoch - 6ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.7460 - 39ms/epoch - 7ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.6522 - 38ms/epoch - 6ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.5614 - 40ms/epoch - 7ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 1.4848 - 35ms/epoch - 6ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 1.4080 - 39ms/epoch - 7ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 1.3494 - 36ms/epoch - 6ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 1.2908 - 35ms/epoch - 6ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 1.2414 - 34ms/epoch - 6ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.1970 - 40ms/epoch - 7ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.1555 - 37ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.1195 - 39ms/epoch - 6ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.0881 - 34ms/epoch - 6ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.0592 - 40ms/epoch - 7ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.0313 - 37ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 1.0122 - 41ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.1017 - 826ms/epoch - 413ms/step
# [CV] END ...............................l1_reg=0, n_units=30; total time=   7.6s
# Epoch 1/20
# 2/2 - 5s - loss: 1.2672 - 5s/epoch - 3s/step
# Epoch 2/20
# 2/2 - 0s - loss: 1.2561 - 19ms/epoch - 9ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 1.2460 - 20ms/epoch - 10ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 1.2362 - 17ms/epoch - 9ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.2262 - 18ms/epoch - 9ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.2185 - 20ms/epoch - 10ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.2094 - 12ms/epoch - 6ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.1998 - 16ms/epoch - 8ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.1920 - 16ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.1820 - 16ms/epoch - 8ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.1737 - 16ms/epoch - 8ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.1629 - 16ms/epoch - 8ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.1557 - 16ms/epoch - 8ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.1458 - 16ms/epoch - 8ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.1372 - 16ms/epoch - 8ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.1289 - 29ms/epoch - 15ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.1203 - 22ms/epoch - 11ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.1110 - 18ms/epoch - 9ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.1052 - 34ms/epoch - 17ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.0950 - 19ms/epoch - 9ms/step
# 2/2 - 1s - loss: 0.5631 - 711ms/epoch - 356ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   7.3s
# Epoch 1/20
# 3/3 - 4s - loss: 0.9683 - 4s/epoch - 1s/step
# Epoch 2/20
# 3/3 - 0s - loss: 0.9545 - 16ms/epoch - 5ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 0.9422 - 16ms/epoch - 5ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 0.9275 - 36ms/epoch - 12ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 0.9167 - 20ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 0.9049 - 31ms/epoch - 10ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 0.8923 - 25ms/epoch - 8ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 0.8830 - 35ms/epoch - 12ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 0.8710 - 22ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 0.8608 - 20ms/epoch - 7ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 0.8512 - 21ms/epoch - 7ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 0.8422 - 22ms/epoch - 7ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 0.8334 - 20ms/epoch - 7ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 0.8233 - 20ms/epoch - 7ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 0.8163 - 20ms/epoch - 7ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 0.8064 - 21ms/epoch - 7ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 0.7997 - 20ms/epoch - 7ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 0.7916 - 20ms/epoch - 7ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 0.7858 - 21ms/epoch - 7ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 0.7776 - 20ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.1951 - 655ms/epoch - 327ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   5.7s
# Epoch 1/20
# 4/4 - 4s - loss: 1.0979 - 4s/epoch - 1s/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.0813 - 27ms/epoch - 7ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.0638 - 26ms/epoch - 6ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.0498 - 25ms/epoch - 6ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.0336 - 26ms/epoch - 7ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.0192 - 25ms/epoch - 6ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.0053 - 24ms/epoch - 6ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 0.9935 - 25ms/epoch - 6ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 0.9800 - 25ms/epoch - 6ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 0.9687 - 26ms/epoch - 7ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 0.9580 - 24ms/epoch - 6ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 0.9466 - 25ms/epoch - 6ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 0.9374 - 25ms/epoch - 6ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 0.9276 - 27ms/epoch - 7ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 0.9181 - 23ms/epoch - 6ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 0.9102 - 18ms/epoch - 4ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 0.9020 - 31ms/epoch - 8ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 0.8945 - 31ms/epoch - 8ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 0.8863 - 31ms/epoch - 8ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 0.8798 - 16ms/epoch - 4ms/step
# 2/2 - 1s - loss: 1.0523 - 710ms/epoch - 355ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   6.0s
# Epoch 1/20
# 5/5 - 4s - loss: 1.1396 - 4s/epoch - 801ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.1195 - 31ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.0999 - 39ms/epoch - 8ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.0808 - 16ms/epoch - 3ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.0632 - 16ms/epoch - 3ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.0471 - 31ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.0320 - 31ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.0177 - 31ms/epoch - 6ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.0039 - 31ms/epoch - 6ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 0.9887 - 31ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 0.9780 - 31ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 0.9656 - 31ms/epoch - 6ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 0.9540 - 31ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 0.9437 - 31ms/epoch - 6ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 0.9342 - 31ms/epoch - 6ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 0.9243 - 31ms/epoch - 6ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 0.9153 - 31ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 0.9080 - 31ms/epoch - 6ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 0.8999 - 31ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 0.8932 - 31ms/epoch - 6ms/step
# 2/2 - 1s - loss: 0.9397 - 727ms/epoch - 363ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   6.7s
# Epoch 1/20
# 6/6 - 4s - loss: 1.1475 - 4s/epoch - 647ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.1194 - 31ms/epoch - 5ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.0967 - 31ms/epoch - 5ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.0770 - 16ms/epoch - 3ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.0562 - 31ms/epoch - 5ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.0374 - 31ms/epoch - 5ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.0196 - 31ms/epoch - 5ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.0042 - 31ms/epoch - 5ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 0.9888 - 16ms/epoch - 3ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 0.9742 - 31ms/epoch - 5ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 0.9615 - 47ms/epoch - 8ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 0.9496 - 31ms/epoch - 5ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 0.9391 - 31ms/epoch - 5ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 0.9270 - 31ms/epoch - 5ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 0.9187 - 31ms/epoch - 5ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 0.9087 - 31ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 0.9016 - 31ms/epoch - 5ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 0.8924 - 31ms/epoch - 5ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 0.8871 - 62ms/epoch - 10ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 0.8798 - 30ms/epoch - 5ms/step
# 2/2 - 1s - loss: 1.0238 - 690ms/epoch - 345ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=   5.9s
# Epoch 1/20
# 2/2 - 4s - loss: 1.8622 - 4s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 1.8396 - 22ms/epoch - 11ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 1.8176 - 17ms/epoch - 8ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 1.7963 - 16ms/epoch - 8ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.7769 - 17ms/epoch - 8ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.7555 - 16ms/epoch - 8ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.7354 - 16ms/epoch - 8ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.7164 - 16ms/epoch - 8ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.6983 - 17ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.6789 - 18ms/epoch - 9ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.6615 - 16ms/epoch - 8ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.6440 - 18ms/epoch - 9ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.6268 - 16ms/epoch - 8ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.6101 - 15ms/epoch - 8ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.5932 - 17ms/epoch - 8ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.5764 - 17ms/epoch - 8ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.5597 - 16ms/epoch - 8ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.5441 - 17ms/epoch - 8ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.5270 - 17ms/epoch - 8ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.5126 - 17ms/epoch - 8ms/step
# 2/2 - 1s - loss: 0.7492 - 688ms/epoch - 344ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.3s
# Epoch 1/20
# 3/3 - 4s - loss: 1.4335 - 4s/epoch - 1s/step
# Epoch 2/20
# 3/3 - 0s - loss: 1.3933 - 31ms/epoch - 10ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 1.3574 - 20ms/epoch - 7ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 1.3232 - 24ms/epoch - 8ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 1.2926 - 19ms/epoch - 6ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 1.2643 - 20ms/epoch - 7ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 1.2389 - 20ms/epoch - 7ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 1.2188 - 21ms/epoch - 7ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 1.1950 - 21ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 1.1734 - 21ms/epoch - 7ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 1.1555 - 20ms/epoch - 7ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 1.1361 - 21ms/epoch - 7ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 1.1162 - 21ms/epoch - 7ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 1.0991 - 20ms/epoch - 7ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 1.0815 - 23ms/epoch - 8ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.0637 - 20ms/epoch - 7ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.0471 - 20ms/epoch - 7ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.0328 - 22ms/epoch - 7ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.0156 - 22ms/epoch - 7ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 1.0002 - 20ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.4463 - 562ms/epoch - 281ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   6.0s
# Epoch 1/20
# 4/4 - 3s - loss: 1.5815 - 3s/epoch - 849ms/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.5362 - 41ms/epoch - 10ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.4892 - 24ms/epoch - 6ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.4477 - 26ms/epoch - 6ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.4131 - 25ms/epoch - 6ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.3775 - 23ms/epoch - 6ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.3458 - 24ms/epoch - 6ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 1.3158 - 24ms/epoch - 6ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 1.2880 - 24ms/epoch - 6ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 1.2621 - 26ms/epoch - 7ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 1.2348 - 24ms/epoch - 6ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 1.2136 - 24ms/epoch - 6ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 1.1899 - 23ms/epoch - 6ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 1.1683 - 42ms/epoch - 11ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 1.1488 - 34ms/epoch - 9ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 1.1289 - 23ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 1.1100 - 23ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 1.0927 - 24ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.0770 - 22ms/epoch - 6ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.0589 - 24ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.2001 - 723ms/epoch - 361ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.3s
# Epoch 1/20
# 5/5 - 4s - loss: 1.6151 - 4s/epoch - 713ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.5619 - 46ms/epoch - 9ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.5088 - 34ms/epoch - 7ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.4616 - 28ms/epoch - 6ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.4169 - 27ms/epoch - 5ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.3813 - 27ms/epoch - 5ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.3414 - 28ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.3118 - 28ms/epoch - 6ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.2796 - 29ms/epoch - 6ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 1.2487 - 27ms/epoch - 5ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 1.2213 - 28ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 1.1938 - 27ms/epoch - 5ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 1.1683 - 28ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 1.1469 - 25ms/epoch - 5ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 1.1231 - 28ms/epoch - 6ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 1.1032 - 27ms/epoch - 5ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.0810 - 26ms/epoch - 5ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.0637 - 16ms/epoch - 3ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.0479 - 16ms/epoch - 3ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.0307 - 16ms/epoch - 3ms/step
# 2/2 - 1s - loss: 1.1199 - 641ms/epoch - 320ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.4s
# Epoch 1/20
# 6/6 - 4s - loss: 1.6340 - 4s/epoch - 640ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.5630 - 35ms/epoch - 6ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.5043 - 33ms/epoch - 5ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.4473 - 34ms/epoch - 6ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.4018 - 34ms/epoch - 6ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.3607 - 33ms/epoch - 6ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.3165 - 31ms/epoch - 5ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.2762 - 32ms/epoch - 5ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 1.2456 - 34ms/epoch - 6ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 1.2107 - 31ms/epoch - 5ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 1.1825 - 31ms/epoch - 5ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 1.1533 - 31ms/epoch - 5ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 1.1257 - 31ms/epoch - 5ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.1011 - 31ms/epoch - 5ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.0804 - 31ms/epoch - 5ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.0590 - 31ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.0409 - 31ms/epoch - 5ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.0201 - 31ms/epoch - 5ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.0054 - 31ms/epoch - 5ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 0.9891 - 31ms/epoch - 5ms/step
# 2/2 - 1s - loss: 1.1009 - 597ms/epoch - 299ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=   5.7s
# Epoch 1/20
# 2/2 - 4s - loss: 2.1231 - 4s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 2.0814 - 16ms/epoch - 8ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 2.0401 - 16ms/epoch - 8ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 2.0014 - 16ms/epoch - 8ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 1.9711 - 16ms/epoch - 8ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 1.9386 - 31ms/epoch - 16ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 1.9046 - 16ms/epoch - 8ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 1.8722 - 16ms/epoch - 8ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 1.8429 - 16ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 1.8146 - 16ms/epoch - 8ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 1.7855 - 29ms/epoch - 15ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 1.7589 - 17ms/epoch - 8ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 1.7310 - 36ms/epoch - 18ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 1.7047 - 23ms/epoch - 11ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 1.6823 - 17ms/epoch - 8ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 1.6549 - 17ms/epoch - 8ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 1.6336 - 16ms/epoch - 8ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 1.6074 - 18ms/epoch - 9ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 1.5854 - 17ms/epoch - 8ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 1.5623 - 17ms/epoch - 8ms/step
# 2/2 - 1s - loss: 0.7648 - 654ms/epoch - 327ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   5.7s
# Epoch 1/20
# 3/3 - 3s - loss: 1.6411 - 3s/epoch - 1s/step
# Epoch 2/20
# 3/3 - 0s - loss: 1.5703 - 16ms/epoch - 5ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 1.5083 - 31ms/epoch - 10ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 1.4503 - 16ms/epoch - 5ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 1.4066 - 31ms/epoch - 10ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 1.3637 - 16ms/epoch - 5ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 1.3268 - 16ms/epoch - 5ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 1.2887 - 16ms/epoch - 5ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 1.2543 - 16ms/epoch - 5ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 1.2267 - 16ms/epoch - 5ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 1.1947 - 16ms/epoch - 5ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 1.1679 - 31ms/epoch - 10ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 1.1419 - 16ms/epoch - 5ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 1.1146 - 31ms/epoch - 10ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 1.0919 - 16ms/epoch - 5ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.0673 - 16ms/epoch - 5ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.0479 - 16ms/epoch - 5ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.0295 - 16ms/epoch - 5ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.0087 - 31ms/epoch - 10ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 0.9933 - 16ms/epoch - 5ms/step
# 2/2 - 1s - loss: 1.5184 - 696ms/epoch - 348ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   5.2s
# Epoch 1/20
# 4/4 - 4s - loss: 1.8707 - 4s/epoch - 892ms/step
# Epoch 2/20
# 4/4 - 0s - loss: 1.7675 - 22ms/epoch - 5ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 1.6931 - 22ms/epoch - 6ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 1.6239 - 23ms/epoch - 6ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 1.5717 - 22ms/epoch - 5ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 1.5214 - 22ms/epoch - 5ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 1.4765 - 29ms/epoch - 7ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 1.4361 - 30ms/epoch - 7ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 1.3905 - 42ms/epoch - 11ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 1.3526 - 22ms/epoch - 6ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 1.3131 - 23ms/epoch - 6ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 1.2787 - 22ms/epoch - 6ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 1.2456 - 23ms/epoch - 6ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 1.2221 - 23ms/epoch - 6ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 1.1873 - 23ms/epoch - 6ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 1.1588 - 23ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 1.1350 - 24ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 1.1118 - 24ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.0892 - 24ms/epoch - 6ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.0690 - 23ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.2038 - 619ms/epoch - 309ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   5.4s
# Epoch 1/20
# 5/5 - 4s - loss: 1.9224 - 4s/epoch - 708ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 1.7973 - 31ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 1.7013 - 56ms/epoch - 11ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 1.6349 - 34ms/epoch - 7ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 1.5698 - 33ms/epoch - 7ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 1.5082 - 33ms/epoch - 7ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 1.4537 - 27ms/epoch - 5ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 1.4005 - 28ms/epoch - 6ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 1.3545 - 28ms/epoch - 6ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 1.3085 - 27ms/epoch - 5ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 1.2687 - 28ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 1.2311 - 30ms/epoch - 6ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 1.1961 - 29ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 1.1633 - 27ms/epoch - 5ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 1.1361 - 26ms/epoch - 5ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 1.1092 - 28ms/epoch - 6ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.0840 - 28ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.0600 - 36ms/epoch - 7ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.0403 - 30ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.0211 - 29ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.1087 - 1s/epoch - 668ms/step
# [CV] END ...........................l1_reg=0.001, n_units=20; total time=   6.7s
# Epoch 1/20
# 6/6 - 3s - loss: 1.9478 - 3s/epoch - 571ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 1.7892 - 31ms/epoch - 5ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 1.6913 - 31ms/epoch - 5ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 1.6078 - 31ms/epoch - 5ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 1.5345 - 46ms/epoch - 8ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 1.4690 - 58ms/epoch - 10ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 1.4041 - 46ms/epoch - 8ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 1.3476 - 32ms/epoch - 5ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 1.2971 - 32ms/epoch - 5ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 1.2517 - 33ms/epoch - 6ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 1.2099 - 32ms/epoch - 5ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 1.1690 - 31ms/epoch - 5ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 1.1366 - 31ms/epoch - 5ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.1034 - 32ms/epoch - 5ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.0767 - 33ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.0517 - 32ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.0278 - 33ms/epoch - 6ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.0077 - 32ms/epoch - 5ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 0.9877 - 34ms/epoch - 6ms/step
# Epoch 20/20
# ...
# Epoch 13/20
# 6/6 - 0s - loss: 2.0381 - 45ms/epoch - 8ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 1.9992 - 36ms/epoch - 6ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.9589 - 37ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.9232 - 36ms/epoch - 6ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.8869 - 34ms/epoch - 6ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.8530 - 33ms/epoch - 6ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.8207 - 33ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 1.7878 - 35ms/epoch - 6ms/step
# 2/2 - 1s - loss: 2.1950 - 851ms/epoch - 425ms/step
# [CV] END .............................l1_reg=0.1, n_units=10; total time=   6.9s
# Epoch 1/20
# 2/2 - 5s - loss: 2.5758 - 5s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 2.5494 - 16ms/epoch - 8ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 2.5238 - 16ms/epoch - 8ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 2.4982 - 16ms/epoch - 8ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 2.4730 - 17ms/epoch - 8ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 2.4471 - 17ms/epoch - 8ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 2.4228 - 21ms/epoch - 11ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 2.3983 - 17ms/epoch - 9ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 2.3733 - 17ms/epoch - 8ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 2.3496 - 19ms/epoch - 9ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 2.3254 - 18ms/epoch - 9ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 2.3019 - 18ms/epoch - 9ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 2.2779 - 18ms/epoch - 9ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 2.2546 - 20ms/epoch - 10ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 2.2311 - 21ms/epoch - 10ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 2.2083 - 20ms/epoch - 10ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 2.1848 - 20ms/epoch - 10ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 2.1623 - 17ms/epoch - 8ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 2.1404 - 18ms/epoch - 9ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 2.1184 - 20ms/epoch - 10ms/step
# 2/2 - 1s - loss: 2.0073 - 1s/epoch - 729ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   7.2s
# Epoch 1/20
# 3/3 - 5s - loss: 2.5077 - 5s/epoch - 2s/step
# Epoch 2/20
# 3/3 - 0s - loss: 2.4696 - 24ms/epoch - 8ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 2.4334 - 34ms/epoch - 11ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 2.3963 - 22ms/epoch - 7ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 2.3598 - 22ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 2.3246 - 23ms/epoch - 8ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 2.2889 - 23ms/epoch - 8ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 2.2543 - 20ms/epoch - 7ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 2.2202 - 22ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 2.1865 - 22ms/epoch - 7ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 2.1524 - 20ms/epoch - 7ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 2.1200 - 21ms/epoch - 7ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 2.0873 - 22ms/epoch - 7ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 2.0548 - 21ms/epoch - 7ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 2.0243 - 21ms/epoch - 7ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 1.9931 - 21ms/epoch - 7ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 1.9636 - 21ms/epoch - 7ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 1.9349 - 21ms/epoch - 7ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.9068 - 22ms/epoch - 7ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 1.8785 - 26ms/epoch - 9ms/step
# 2/2 - 1s - loss: 2.7325 - 737ms/epoch - 369ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   6.3s
# Epoch 1/20
# 4/4 - 5s - loss: 2.8369 - 5s/epoch - 1s/step
# Epoch 2/20
# 4/4 - 0s - loss: 2.7813 - 27ms/epoch - 7ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 2.7287 - 27ms/epoch - 7ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 2.6752 - 29ms/epoch - 7ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 2.6236 - 25ms/epoch - 6ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 2.5724 - 24ms/epoch - 6ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 2.5210 - 28ms/epoch - 7ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 2.4736 - 39ms/epoch - 10ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 2.4246 - 31ms/epoch - 8ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 2.3752 - 31ms/epoch - 8ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 2.3297 - 33ms/epoch - 8ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 2.2841 - 34ms/epoch - 9ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 2.2406 - 36ms/epoch - 9ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 2.1990 - 26ms/epoch - 7ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 2.1556 - 24ms/epoch - 6ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 2.1157 - 24ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 2.0771 - 25ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 2.0406 - 25ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 2.0027 - 25ms/epoch - 6ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.9673 - 23ms/epoch - 6ms/step
# 2/2 - 1s - loss: 2.4200 - 748ms/epoch - 374ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   6.7s
# Epoch 1/20
# 5/5 - 4s - loss: 3.0043 - 4s/epoch - 837ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 2.9313 - 32ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 2.8601 - 36ms/epoch - 7ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 2.7907 - 32ms/epoch - 6ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 2.7212 - 29ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 2.6542 - 30ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 2.5898 - 29ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 2.5236 - 27ms/epoch - 5ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 2.4603 - 26ms/epoch - 5ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 2.3991 - 26ms/epoch - 5ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 2.3414 - 27ms/epoch - 5ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 2.2846 - 27ms/epoch - 5ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 2.2280 - 26ms/epoch - 5ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 2.1782 - 28ms/epoch - 6ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 2.1273 - 27ms/epoch - 5ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 2.0807 - 27ms/epoch - 5ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 2.0350 - 30ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.9913 - 53ms/epoch - 11ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.9489 - 29ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.9075 - 38ms/epoch - 8ms/step
# 2/2 - 1s - loss: 1.8465 - 711ms/epoch - 356ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   7.0s
# Epoch 1/20
# 6/6 - 5s - loss: 2.9664 - 5s/epoch - 785ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 2.8806 - 33ms/epoch - 6ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 2.7965 - 39ms/epoch - 6ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 2.7138 - 40ms/epoch - 7ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 2.6364 - 38ms/epoch - 6ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 2.5549 - 46ms/epoch - 8ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 2.4815 - 47ms/epoch - 8ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 2.4088 - 33ms/epoch - 6ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 2.3369 - 31ms/epoch - 5ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 2.2707 - 32ms/epoch - 5ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 2.2067 - 30ms/epoch - 5ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 2.1447 - 31ms/epoch - 5ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 2.0899 - 31ms/epoch - 5ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 2.0351 - 31ms/epoch - 5ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.9821 - 31ms/epoch - 5ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.9310 - 32ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.8813 - 35ms/epoch - 6ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.8364 - 31ms/epoch - 5ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.7913 - 34ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 1.7490 - 38ms/epoch - 6ms/step
# 2/2 - 1s - loss: 2.0525 - 699ms/epoch - 350ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   6.8s
# Epoch 1/20
# 2/2 - 5s - loss: 2.8156 - 5s/epoch - 2s/step
# Epoch 2/20
# 2/2 - 0s - loss: 2.7781 - 16ms/epoch - 8ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 2.7428 - 15ms/epoch - 7ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 2.7072 - 15ms/epoch - 7ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 2.6715 - 15ms/epoch - 7ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 2.6370 - 16ms/epoch - 8ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 2.6032 - 15ms/epoch - 8ms/step
# Epoch 8/20
# 2/2 - 0s - loss: 2.5697 - 14ms/epoch - 7ms/step
# Epoch 9/20
# 2/2 - 0s - loss: 2.5364 - 15ms/epoch - 7ms/step
# Epoch 10/20
# 2/2 - 0s - loss: 2.5028 - 15ms/epoch - 8ms/step
# Epoch 11/20
# 2/2 - 0s - loss: 2.4710 - 15ms/epoch - 7ms/step
# Epoch 12/20
# 2/2 - 0s - loss: 2.4390 - 15ms/epoch - 7ms/step
# Epoch 13/20
# 2/2 - 0s - loss: 2.4085 - 15ms/epoch - 7ms/step
# Epoch 14/20
# 2/2 - 0s - loss: 2.3767 - 15ms/epoch - 8ms/step
# Epoch 15/20
# 2/2 - 0s - loss: 2.3469 - 17ms/epoch - 8ms/step
# Epoch 16/20
# 2/2 - 0s - loss: 2.3160 - 15ms/epoch - 8ms/step
# Epoch 17/20
# 2/2 - 0s - loss: 2.2857 - 15ms/epoch - 8ms/step
# Epoch 18/20
# 2/2 - 0s - loss: 2.2571 - 16ms/epoch - 8ms/step
# Epoch 19/20
# 2/2 - 0s - loss: 2.2284 - 15ms/epoch - 8ms/step
# Epoch 20/20
# 2/2 - 0s - loss: 2.1998 - 27ms/epoch - 14ms/step
# 2/2 - 1s - loss: 2.1462 - 740ms/epoch - 370ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.3s
# Epoch 1/20
# 3/3 - 5s - loss: 2.7722 - 5s/epoch - 2s/step
# Epoch 2/20
# 3/3 - 0s - loss: 2.7190 - 21ms/epoch - 7ms/step
# Epoch 3/20
# 3/3 - 0s - loss: 2.6668 - 23ms/epoch - 8ms/step
# Epoch 4/20
# 3/3 - 0s - loss: 2.6153 - 22ms/epoch - 7ms/step
# Epoch 5/20
# 3/3 - 0s - loss: 2.5657 - 22ms/epoch - 7ms/step
# Epoch 6/20
# 3/3 - 0s - loss: 2.5180 - 23ms/epoch - 8ms/step
# Epoch 7/20
# 3/3 - 0s - loss: 2.4692 - 24ms/epoch - 8ms/step
# Epoch 8/20
# 3/3 - 0s - loss: 2.4230 - 24ms/epoch - 8ms/step
# Epoch 9/20
# 3/3 - 0s - loss: 2.3785 - 21ms/epoch - 7ms/step
# Epoch 10/20
# 3/3 - 0s - loss: 2.3339 - 23ms/epoch - 8ms/step
# Epoch 11/20
# 3/3 - 0s - loss: 2.2890 - 22ms/epoch - 7ms/step
# Epoch 12/20
# 3/3 - 0s - loss: 2.2457 - 21ms/epoch - 7ms/step
# Epoch 13/20
# 3/3 - 0s - loss: 2.2035 - 26ms/epoch - 9ms/step
# Epoch 14/20
# 3/3 - 0s - loss: 2.1627 - 24ms/epoch - 8ms/step
# Epoch 15/20
# 3/3 - 0s - loss: 2.1222 - 25ms/epoch - 8ms/step
# Epoch 16/20
# 3/3 - 0s - loss: 2.0834 - 24ms/epoch - 8ms/step
# Epoch 17/20
# 3/3 - 0s - loss: 2.0448 - 23ms/epoch - 8ms/step
# Epoch 18/20
# 3/3 - 0s - loss: 2.0066 - 24ms/epoch - 8ms/step
# Epoch 19/20
# 3/3 - 0s - loss: 1.9702 - 26ms/epoch - 9ms/step
# Epoch 20/20
# 3/3 - 0s - loss: 1.9336 - 25ms/epoch - 8ms/step
# 2/2 - 1s - loss: 2.7014 - 1s/epoch - 516ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   7.7s
# Epoch 1/20
# 4/4 - 5s - loss: 3.0884 - 5s/epoch - 1s/step
# Epoch 2/20
# 4/4 - 0s - loss: 3.0120 - 26ms/epoch - 7ms/step
# Epoch 3/20
# 4/4 - 0s - loss: 2.9359 - 27ms/epoch - 7ms/step
# Epoch 4/20
# 4/4 - 0s - loss: 2.8636 - 27ms/epoch - 7ms/step
# Epoch 5/20
# 4/4 - 0s - loss: 2.7919 - 26ms/epoch - 6ms/step
# Epoch 6/20
# 4/4 - 0s - loss: 2.7234 - 28ms/epoch - 7ms/step
# Epoch 7/20
# 4/4 - 0s - loss: 2.6555 - 25ms/epoch - 6ms/step
# Epoch 8/20
# 4/4 - 0s - loss: 2.5893 - 28ms/epoch - 7ms/step
# Epoch 9/20
# 4/4 - 0s - loss: 2.5254 - 29ms/epoch - 7ms/step
# Epoch 10/20
# 4/4 - 0s - loss: 2.4635 - 35ms/epoch - 9ms/step
# Epoch 11/20
# 4/4 - 0s - loss: 2.4041 - 26ms/epoch - 7ms/step
# Epoch 12/20
# 4/4 - 0s - loss: 2.3474 - 25ms/epoch - 6ms/step
# Epoch 13/20
# 4/4 - 0s - loss: 2.2910 - 27ms/epoch - 7ms/step
# Epoch 14/20
# 4/4 - 0s - loss: 2.2363 - 24ms/epoch - 6ms/step
# Epoch 15/20
# 4/4 - 0s - loss: 2.1853 - 25ms/epoch - 6ms/step
# Epoch 16/20
# 4/4 - 0s - loss: 2.1335 - 25ms/epoch - 6ms/step
# Epoch 17/20
# 4/4 - 0s - loss: 2.0854 - 25ms/epoch - 6ms/step
# Epoch 18/20
# 4/4 - 0s - loss: 2.0382 - 25ms/epoch - 6ms/step
# Epoch 19/20
# 4/4 - 0s - loss: 1.9917 - 25ms/epoch - 6ms/step
# Epoch 20/20
# 4/4 - 0s - loss: 1.9453 - 24ms/epoch - 6ms/step
# 2/2 - 1s - loss: 2.3591 - 703ms/epoch - 352ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.7s
# Epoch 1/20
# 5/5 - 5s - loss: 3.2506 - 5s/epoch - 904ms/step
# Epoch 2/20
# 5/5 - 0s - loss: 3.1492 - 31ms/epoch - 6ms/step
# Epoch 3/20
# 5/5 - 0s - loss: 3.0528 - 31ms/epoch - 6ms/step
# Epoch 4/20
# 5/5 - 0s - loss: 2.9574 - 29ms/epoch - 6ms/step
# Epoch 5/20
# 5/5 - 0s - loss: 2.8652 - 32ms/epoch - 6ms/step
# Epoch 6/20
# 5/5 - 0s - loss: 2.7778 - 30ms/epoch - 6ms/step
# Epoch 7/20
# 5/5 - 0s - loss: 2.6882 - 29ms/epoch - 6ms/step
# Epoch 8/20
# 5/5 - 0s - loss: 2.6073 - 34ms/epoch - 7ms/step
# Epoch 9/20
# 5/5 - 0s - loss: 2.5291 - 43ms/epoch - 9ms/step
# Epoch 10/20
# 5/5 - 0s - loss: 2.4531 - 32ms/epoch - 6ms/step
# Epoch 11/20
# 5/5 - 0s - loss: 2.3784 - 30ms/epoch - 6ms/step
# Epoch 12/20
# 5/5 - 0s - loss: 2.3093 - 30ms/epoch - 6ms/step
# Epoch 13/20
# 5/5 - 0s - loss: 2.2433 - 30ms/epoch - 6ms/step
# Epoch 14/20
# 5/5 - 0s - loss: 2.1801 - 28ms/epoch - 6ms/step
# Epoch 15/20
# 5/5 - 0s - loss: 2.1184 - 27ms/epoch - 5ms/step
# Epoch 16/20
# 5/5 - 0s - loss: 2.0571 - 28ms/epoch - 6ms/step
# Epoch 17/20
# 5/5 - 0s - loss: 1.9992 - 28ms/epoch - 6ms/step
# Epoch 18/20
# 5/5 - 0s - loss: 1.9435 - 29ms/epoch - 6ms/step
# Epoch 19/20
# 5/5 - 0s - loss: 1.8906 - 29ms/epoch - 6ms/step
# Epoch 20/20
# 5/5 - 0s - loss: 1.8410 - 33ms/epoch - 7ms/step
# 2/2 - 1s - loss: 1.7940 - 812ms/epoch - 406ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   6.6s
# Epoch 1/20
# 6/6 - 5s - loss: 3.2141 - 5s/epoch - 755ms/step
# Epoch 2/20
# 6/6 - 0s - loss: 3.0983 - 40ms/epoch - 7ms/step
# Epoch 3/20
# 6/6 - 0s - loss: 2.9853 - 34ms/epoch - 6ms/step
# Epoch 4/20
# 6/6 - 0s - loss: 2.8770 - 36ms/epoch - 6ms/step
# Epoch 5/20
# 6/6 - 0s - loss: 2.7720 - 35ms/epoch - 6ms/step
# Epoch 6/20
# 6/6 - 0s - loss: 2.6689 - 39ms/epoch - 6ms/step
# Epoch 7/20
# 6/6 - 0s - loss: 2.5747 - 36ms/epoch - 6ms/step
# Epoch 8/20
# 6/6 - 0s - loss: 2.4826 - 33ms/epoch - 6ms/step
# Epoch 9/20
# 6/6 - 0s - loss: 2.3938 - 34ms/epoch - 6ms/step
# Epoch 10/20
# 6/6 - 0s - loss: 2.3126 - 32ms/epoch - 5ms/step
# Epoch 11/20
# 6/6 - 0s - loss: 2.2330 - 33ms/epoch - 6ms/step
# Epoch 12/20
# 6/6 - 0s - loss: 2.1578 - 33ms/epoch - 6ms/step
# Epoch 13/20
# 6/6 - 0s - loss: 2.0857 - 34ms/epoch - 6ms/step
# Epoch 14/20
# 6/6 - 0s - loss: 2.0147 - 34ms/epoch - 6ms/step
# Epoch 15/20
# 6/6 - 0s - loss: 1.9467 - 33ms/epoch - 6ms/step
# Epoch 16/20
# 6/6 - 0s - loss: 1.8846 - 32ms/epoch - 5ms/step
# Epoch 17/20
# 6/6 - 0s - loss: 1.8249 - 32ms/epoch - 5ms/step
# Epoch 18/20
# 6/6 - 0s - loss: 1.7700 - 34ms/epoch - 6ms/step
# Epoch 19/20
# 6/6 - 0s - loss: 1.7176 - 37ms/epoch - 6ms/step
# Epoch 20/20
# 6/6 - 0s - loss: 1.6662 - 33ms/epoch - 6ms/step
# 2/2 - 1s - loss: 1.9951 - 777ms/epoch - 389ms/step
# [CV] END .............................l1_reg=0.1, n_units=30; total time=   7.6s
# Epoch 1/20
# 8/8 - 4s - loss: 1.3272 - 4s/epoch - 535ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 1.2445 - 40ms/epoch - 5ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 1.1686 - 41ms/epoch - 5ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 1.0912 - 55ms/epoch - 7ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 1.0272 - 79ms/epoch - 10ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 0.9844 - 43ms/epoch - 5ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 0.9416 - 44ms/epoch - 6ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 0.9098 - 41ms/epoch - 5ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 0.8817 - 57ms/epoch - 7ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 0.8732 - 52ms/epoch - 6ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 0.8643 - 48ms/epoch - 6ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 0.8590 - 46ms/epoch - 6ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 0.8562 - 56ms/epoch - 7ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 0.8523 - 40ms/epoch - 5ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 0.8524 - 36ms/epoch - 5ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 0.8494 - 40ms/epoch - 5ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 0.8500 - 37ms/epoch - 5ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 0.8481 - 41ms/epoch - 5ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 0.8459 - 40ms/epoch - 5ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 0.8456 - 42ms/epoch - 5ms/step
# Best: -0.941964 using {'l1_reg': 0, 'n_units': 30}
# -1.334043 (0.389776) with {'l1_reg': 0, 'n_units': 5}
# -1.200248 (0.328157) with {'l1_reg': 0, 'n_units': 10}
# -0.983189 (0.221111) with {'l1_reg': 0, 'n_units': 20}
# -0.941964 (0.163932) with {'l1_reg': 0, 'n_units': 30}
# -1.335342 (0.387642) with {'l1_reg': 0.001, 'n_units': 5}
# -1.211088 (0.324775) with {'l1_reg': 0.001, 'n_units': 10}
# -0.998392 (0.215449) with {'l1_reg': 0.001, 'n_units': 20}
# -0.963585 (0.165677) with {'l1_reg': 0.001, 'n_units': 30}
# -1.410451 (0.391699) with {'l1_reg': 0.01, 'n_units': 5}
# -1.320499 (0.327225) with {'l1_reg': 0.01, 'n_units': 10}
# -1.142956 (0.227525) with {'l1_reg': 0.01, 'n_units': 20}
# -1.118490 (0.178728) with {'l1_reg': 0.01, 'n_units': 30}
# -2.026312 (0.402687) with {'l1_reg': 0.1, 'n_units': 5}
# -2.193092 (0.357637) with {'l1_reg': 0.1, 'n_units': 10}
# -2.211779 (0.320956) with {'l1_reg': 0.1, 'n_units': 20}
# -2.199176 (0.311871) with {'l1_reg': 0.1, 'n_units': 30}

# %% [markdown]
# #### Train cross-validated model

# %% [markdown]
# Si se realizó la búsqueda en cuadrícula, los parámetros n_units y l1_reg con el mejor rendimiento promedio a través de las divisiones de validación cruzada se utilizan para entrenar los modelos en el conjunto de entrenamiento completo. Si no se realizó, se utilizan los valores de la inicialización de params mencionados anteriormente.

# %%
if do_training is True:
    for key in params.keys():
        tf.random.set_seed(0)
        print('Training', key, 'model')
        model = params[key]['function'](params[key]['H'], params[key]['l1_reg'])
        model.fit(x_train, y_train, epochs=max_epochs, 
                  batch_size=batch_size, callbacks=[es], shuffle=False)
        params[key]['model'] = model
# Out:
# Training rnn model
# Epoch 1/20
# 8/8 [==============================] - 4s 15ms/step - loss: 1.1627
# Epoch 2/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1282
# Epoch 3/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0981
# Epoch 4/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0710
# Epoch 5/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0467
# Epoch 6/20
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0249
# Epoch 7/20
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0054
# Epoch 8/20
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9880
# Epoch 9/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9725
# Epoch 10/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9587
# Epoch 11/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9463
# Epoch 12/20
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9353
# Epoch 13/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9255
# Epoch 14/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.9167
# Epoch 15/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9088
# Epoch 16/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9018
# Epoch 17/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8955
# Epoch 18/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8899
# Epoch 19/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8848
# Epoch 20/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8803
# Training gru model
# Epoch 1/20
# 8/8 [==============================] - 5s 14ms/step - loss: 1.7485
# Epoch 2/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.5705
# Epoch 3/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.4215
# Epoch 4/20
# 8/8 [==============================] - 0s 6ms/step - loss: 1.2932
# Epoch 5/20
# 8/8 [==============================] - 0s 6ms/step - loss: 1.1839
# Epoch 6/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0929
# Epoch 7/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.0193
# Epoch 8/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9624
# Epoch 9/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9209
# Epoch 10/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8933
# Epoch 11/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8771
# Epoch 12/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8694
# Epoch 13/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8670
# Epoch 14/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8673
# Epoch 15/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8683
# Epoch 16/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8689
# Epoch 17/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8689
# Epoch 18/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8683
# Epoch 19/20
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8673
# Epoch 20/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8661
# Training lstm model
# Epoch 1/20
# 8/8 [==============================] - 5s 14ms/step - loss: 1.3228
# Epoch 2/20
# 8/8 [==============================] - 0s 8ms/step - loss: 1.2457
# Epoch 3/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1766
# Epoch 4/20
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1117
# Epoch 5/20
# 8/8 [==============================] - 0s 8ms/step - loss: 1.0521
# Epoch 6/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.9992
# Epoch 7/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.9546
# Epoch 8/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.9193
# Epoch 9/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8938
# Epoch 10/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8774
# Epoch 11/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8685
# Epoch 12/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8645
# Epoch 13/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8631
# Epoch 14/20
# 8/8 [==============================] - 0s 8ms/step - loss: 0.8626
# Epoch 15/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8622
# Epoch 16/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8615
# Epoch 17/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8606
# Epoch 18/20
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8596
# Epoch 19/20
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8587
# Epoch 20/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8578

# %%
for key in params.keys():
    params[key]['model'].save('RNNs-Ivan-SAVED-' + key + '.hdf5', overwrite=True)  # creates a HDF5 file

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Predicción</h2>

# %% [markdown]
# Ahora aplicaremos los modelos RNN ajustados al conjunto de entrenamiento y al conjunto de prueba por separado. Luego podemos evaluar informalmente el grado de sobreajuste

# %%
y_train= (y_train*sigma)+mu
y_test=(y_test*sigma)+mu

# %%
for key in params.keys():
    model = params[key]['model']
    model.summary()
    
    params[key]['pred_train'] = model.predict(x_train, verbose=1)
    params[key]['pred_train']=(params[key]['pred_train']*sigma)+mu
    params[key]['MSE_train'] = mean_squared_error(y_train, params[key]['pred_train'])
    
    params[key]['pred_test'] = model.predict(x_test, verbose=1) 
    params[key]['pred_test']=(params[key]['pred_test']*sigma)+mu
    params[key]['MSE_test'] = mean_squared_error(y_test, params[key]['pred_test'])
# Out:
# Model: "sequential_243"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_81 (SimpleRNN)   (None, 5)                 35
#
#  dense_243 (Dense)           (None, 1)                 6
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 16ms/step
# Model: "sequential_244"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_81 (GRU)                (None, 20)                1380
#
#  dense_244 (Dense)           (None, 1)                 21
#
# =================================================================
# Total params: 1,401
# Trainable params: 1,401
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Model: "sequential_245"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_81 (LSTM)              (None, 30)                3840
#
#  dense_245 (Dense)           (None, 1)                 31
#
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 8ms/step

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;"> Rendimiento del modelo</h2>

# %% [markdown]
# Finalmente evaluar el rendimiento del modelo dentro y fuera de muestra usando el MSE. Esperamos que el error medio sea mayor en el conjunto de prueba que en el conjunto de entrenamiento.

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Devolviendo los valores a la escala original</h2>

# %%
print(sigma)
print(mu)
stdize_output = lambda x: (x *sigma) +mu
df_train = df_train.apply(stdize_output)
df_test = df_test.apply(stdize_output)
# Out:
# 48.97102603165779
# 124.08225233644858

# %%
d_train = df[use_features].iloc[:split]
d_test = df[use_features].iloc[split:]
print(d_train)
print(d_test)
# Out:
#               KMS
# DATE
# 2018-12-31   17.3
# 2019-01-07   86.4
# 2019-01-14  107.3
# 2019-01-21  163.1
# 2019-01-28  153.5
# ...           ...
# 2023-01-02  200.0
# 2023-01-09  198.4
# 2023-01-16  181.1
# 2023-01-23  203.5
# 2023-01-30  152.2
#
# [214 rows x 1 columns]
#               KMS
# DATE
# 2023-02-06  147.2
# 2023-02-13   73.4
# 2023-02-20   52.9
# 2023-02-27   75.5
# 2023-03-06  133.5
# 2023-03-13  179.1
# 2023-03-20  106.3
# 2023-03-27  211.0
# 2023-04-03   71.5
# 2023-04-10   98.0
# 2023-04-17  174.3
# 2023-04-24  182.0
# 2023-05-01  178.5
# 2023-05-08  164.4
# 2023-05-15   91.2
# 2023-05-22  129.9
# 2023-05-29  180.5
# 2023-06-05  172.4
# 2023-06-12  168.4
# 2023-06-19  133.9
# 2023-06-26  154.8
# 2023-07-03   72.2
# 2023-07-10  171.0
# 2023-07-17   54.9
# 2023-07-24  107.9
# 2023-07-31   13.3
# 2023-08-07  200.7
# 2023-08-14  122.6
# 2023-08-21  190.9
# 2023-08-28  186.3
# 2023-09-04  185.9
# 2023-09-11  106.9
# 2023-09-18  157.4
# 2023-09-25   35.2
# 2023-10-02  140.6
# 2023-10-09  173.4
# 2023-10-16  115.6
# 2023-10-23  130.5
# 2023-10-30   67.9
# 2023-11-06  146.9
# 2023-11-13  123.5
# 2023-11-20   81.0
# 2023-11-27  146.8
# 2023-12-04  143.6
# 2023-12-11  188.8
# 2023-12-18  202.1
# 2023-12-25  126.2
# 2024-01-01  206.3
# 2024-01-08  211.0
# 2024-01-15  202.2
# 2024-01-22  200.9
# 2024-01-29  160.7
# 2024-02-05  135.7
# 2024-02-12  121.8

# %%
print(params.keys())
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
max_pts = 10**4
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable. 

fig = plt.figure(figsize=(15,8))
x_vals = y_train_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_train'][l:u:ds]
    label = params[key]['label'] + ' (train MSE: %.2e)' % params[key]['MSE_train']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_train[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Training)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_test'][l:u:ds]
    label = params[key]['label'] + ' (test MSE: %.2e)' % params[key]['MSE_test']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_test[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Testing)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # e.g. (None, 100000) lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_test'][l:u:ds] - y_test[l:u:ds]
    label = params[key]['label'] + ' (test MSE: %.2e)' % params[key]['MSE_test']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
plt.axhline(0, linewidth=0.8)
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=80)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}-Y$', fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Error (Testing)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot - e.g. (None, 10000)
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_train_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_train'][l:u:ds] - y_train[l:u:ds]
    label = params[key]['label'] + ' (train MSE: %.2e)' % params[key]['MSE_train']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
plt.axhline(0, linewidth=0.8)
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=80)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}-Y$', fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Error (Training)', fontsize=16);

# %% [markdown]
# <h2 style="color: #e67e22; text-align: left;">Diagnóstico del modelo</h2>

# %% [markdown]
# Un modelo ajustado de series temporales debe ser examinado para la subajustado con una prueba de ruido blanco. Analizamos los residuos del modelo (es decir, el error) para determinar si es ruido blanco o si está autocorrelacionado. En el último caso, esto proporciona evidencia estadística de que se necesitan más rezagos en la RNN.

# %%
# number of samples to use for computing test statistic
n = 100000

# %%
params.keys()
# Out:
# dict_keys(['rnn', 'gru', 'lstm'])

# %%
key = 'lstm'
predicted = params[key]['pred_test']
residual = y_test[-n:] - predicted[-n:]

# %%
statistic_lb = sm.stats.diagnostic.acorr_ljungbox(residual, lags=20, boxpierce=False,return_df=True)

# %%
statistic_lb
# Out:
#       lb_stat  lb_pvalue
# 1    0.801866   0.370536
# 2    0.873913   0.646000
# 3    2.686792   0.442477
# 4    2.906056   0.573668
# 5    2.944806   0.708495
# 6    5.089645   0.532368
# 7    6.990755   0.429843
# 8    6.999883   0.536645
# 9    8.018772   0.532256
# 10   8.122756   0.616848
# 11   8.447337   0.672760
# 12   8.498602   0.745054
# 13   9.784482   0.711456
# 14  12.767398   0.544915
# 15  13.068944   0.596973
# 16  13.071717   0.667507
# 17  13.595856   0.695475
# 18  13.710341   0.747769
# 19  17.053849   0.586220
# 20  20.021822   0.456565

# %% [markdown]
# La prueba puede ser consumidora de tiempo y seleccionamos un subconjunto de los residuos. Aquí simplemente establecemos el número máximo de rezagos en 20. En los resultados a continuación, encontramos que los valores p son todos mayores que 0.01, lo que indica que NO podemos rechazar la hipótesis nula con un nivel de confianza del 99% para cualquier rezago. Esto es evidencia sólida de que el modelo no está subajustado y se necesitan más rezagos en nuestro modelo.. Por lo tanto, no hay peligro de sobreajuste al aumentar el rezago, aunque habrá un aumento en el tiempo de entrenamiento.
